# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint

# %%
url = 'https://www.trustpilot.com/'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'lxml')

# %%
# Get all the divs
divs = soup.find_all('div')

# %%
divs_texts = [div.get_text(strip=True) for div in divs]

# %%
divs_texts
# Out:
# ['Write a reviewCategoriesBlogLog inFor businessesFor businessesLog inWrite a reviewCategoriesBlogFind a company you can trustDiscover, read, and write reviewsBought something recently?Write a reviewWhat are you looking for?See moreBankTravel Insurance CompanyCar DealerFurniture StoreJewelry StoreClothing StoreElectronics & TechnologyFitness and Nutrition ServicePet StoreEnergy SupplierReal Estate AgentsInsurance AgencyBedroom Furniture StoreActivewear StoreWomen\'s Clothing StoreMen\'s Clothing StoreBicycle StoreShoe StoreMortgage BrokerAppliance StoreCosmetics StoreElectronics StoreGarden CenterTravel AgencyLooking to grow your business?Strengthen your reputation with reviews on Trustpilot.Get startedBest in BankSee moreLendingClublendingclub.com4.7(9404)BankFivewww.bankfive.com4.7(5251)DuGood Credit Unionwww.dugood.org4.7(4429)Credit Union of New Jerseywww.cunj.com4.7(4363)Help millions make the right choiceHelp millions make the right choiceShare your experience on Trustpilot, where reviews make a difference.Login or sign upBest in Travel Insurance CompanySee moreAARDYaardy.com4.9(42106)TripInsure101tripinsure101.com4.9(3279)MexiPass International Insurance Serviceswww.mexipass.com4.9(1903)Travel Defenderstraveldefenders.com4.9(1772)We’re TrustpilotWe’re TrustpilotWe’re a review platform that’s open to everyone. Our vision is to become the universal symbol of trust — by empowering people to shop with confidence, and helping companies improve.What we doOur new Trust Report has landed!Find out which actions we’ve taken to protect you and promote trust on our platform.Take a lookRecent reviewsEmilioNordVPN is a SCAM.  DO NOT use their service, and DEFINITELY DO NOT RENEW if you are already a customer.  Their business practices prove that they HATE their repeat customers.  They make it seem like they\'re giving you a deal and as soon as they gain your trust, they DRAMATICALLY OVERCHARGE you when your service renews automatically.  You need to watch them with a microscope if you want to avoid being charged ALMOST DOUBLE for their services.  If you want to save time and a lot of headaches, JUST USE ANOTHER SERVICE.\n\nI started with NordVPN three years ago before it became a total scam.  Before, it was a pretty good VPN option with a fair price and quality services.  In 2022 I purchased a subscription which was set to be automatically renewed the year after.  Before my renewal I got an email from NordVPN offering two years for under 100 dollars (I think it was 90 dollars).  This was a great price so I was very happy with it, until the next year (mind you the original package was sold to me as a TWO-year package, NOT a ONE year package) when I was charged $168 USD to renew for that year.  I actually did not even notice this until the next year in November 2025, when I was being charged again 168 dollars for the same package offered on their website for their Threat Protection Pro package which their website shows is valued at 97.35 dollars (this is without any discount or promotion, just the raw price on their website).  I tried to contact NordVPN by sending multiple emails asking about this.  I have an extension that shows when recievers view my emails, so I know that they recieved and read my emails about this issue.  I got ABSOLUTELY NO REPLY to any of my emails requesting help or clarification with this issue.  Customer support was also absolutely 0 help in solving this.  The company clearly does not care one bit whatsoever about their customers, and at this point their lack of response to this critical issue seems downright malicious.\n\nSo I called my credit card company.  At this point I was still giving NordVPN the benefit of the doubt and assuming that perhaps they had accidentally double-charged me so I asked that the charge be modified to reflect half the value.  In other words, I made my payment to NordVPN around 80 dollars instead of the >160 dollars that they were charging me.  A week later (two months into my subsc ...
#  'Write a reviewCategoriesBlogLog inFor businessesFor businessesLog inWrite a reviewCategoriesBlogFind a company you can trustDiscover, read, and write reviewsBought something recently?Write a reviewWhat are you looking for?See moreBankTravel Insurance CompanyCar DealerFurniture StoreJewelry StoreClothing StoreElectronics & TechnologyFitness and Nutrition ServicePet StoreEnergy SupplierReal Estate AgentsInsurance AgencyBedroom Furniture StoreActivewear StoreWomen\'s Clothing StoreMen\'s Clothing StoreBicycle StoreShoe StoreMortgage BrokerAppliance StoreCosmetics StoreElectronics StoreGarden CenterTravel AgencyLooking to grow your business?Strengthen your reputation with reviews on Trustpilot.Get startedBest in BankSee moreLendingClublendingclub.com4.7(9404)BankFivewww.bankfive.com4.7(5251)DuGood Credit Unionwww.dugood.org4.7(4429)Credit Union of New Jerseywww.cunj.com4.7(4363)Help millions make the right choiceHelp millions make the right choiceShare your experience on Trustpilot, where reviews make a difference.Login or sign upBest in Travel Insurance CompanySee moreAARDYaardy.com4.9(42106)TripInsure101tripinsure101.com4.9(3279)MexiPass International Insurance Serviceswww.mexipass.com4.9(1903)Travel Defenderstraveldefenders.com4.9(1772)We’re TrustpilotWe’re TrustpilotWe’re a review platform that’s open to everyone. Our vision is to become the universal symbol of trust — by empowering people to shop with confidence, and helping companies improve.What we doOur new Trust Report has landed!Find out which actions we’ve taken to protect you and promote trust on our platform.Take a lookRecent reviewsEmilioNordVPN is a SCAM.  DO NOT use their service, and DEFINITELY DO NOT RENEW if you are already a customer.  Their business practices prove that they HATE their repeat customers.  They make it seem like they\'re giving you a deal and as soon as they gain your trust, they DRAMATICALLY OVERCHARGE you when your service renews automatically.  You need to watch them with a microscope if you want to avoid being charged ALMOST DOUBLE for their services.  If you want to save time and a lot of headaches, JUST USE ANOTHER SERVICE.\n\nI started with NordVPN three years ago before it became a total scam.  Before, it was a pretty good VPN option with a fair price and quality services.  In 2022 I purchased a subscription which was set to be automatically renewed the year after.  Before my renewal I got an email from NordVPN offering two years for under 100 dollars (I think it was 90 dollars).  This was a great price so I was very happy with it, until the next year (mind you the original package was sold to me as a TWO-year package, NOT a ONE year package) when I was charged $168 USD to renew for that year.  I actually did not even notice this until the next year in November 2025, when I was being charged again 168 dollars for the same package offered on their website for their Threat Protection Pro package which their website shows is valued at 97.35 dollars (this is without any discount or promotion, just the raw price on their website).  I tried to contact NordVPN by sending multiple emails asking about this.  I have an extension that shows when recievers view my emails, so I know that they recieved and read my emails about this issue.  I got ABSOLUTELY NO REPLY to any of my emails requesting help or clarification with this issue.  Customer support was also absolutely 0 help in solving this.  The company clearly does not care one bit whatsoever about their customers, and at this point their lack of response to this critical issue seems downright malicious.\n\nSo I called my credit card company.  At this point I was still giving NordVPN the benefit of the doubt and assuming that perhaps they had accidentally double-charged me so I asked that the charge be modified to reflect half the value.  In other words, I made my payment to NordVPN around 80 dollars instead of the >160 dollars that they were charging me.  A week later (two months into my subsc ...
#  'Write a reviewCategoriesBlogLog inFor businessesFor businessesLog inWrite a reviewCategoriesBlogFind a company you can trustDiscover, read, and write reviewsBought something recently?Write a reviewWhat are you looking for?See moreBankTravel Insurance CompanyCar DealerFurniture StoreJewelry StoreClothing StoreElectronics & TechnologyFitness and Nutrition ServicePet StoreEnergy SupplierReal Estate AgentsInsurance AgencyBedroom Furniture StoreActivewear StoreWomen\'s Clothing StoreMen\'s Clothing StoreBicycle StoreShoe StoreMortgage BrokerAppliance StoreCosmetics StoreElectronics StoreGarden CenterTravel AgencyLooking to grow your business?Strengthen your reputation with reviews on Trustpilot.Get startedBest in BankSee moreLendingClublendingclub.com4.7(9404)BankFivewww.bankfive.com4.7(5251)DuGood Credit Unionwww.dugood.org4.7(4429)Credit Union of New Jerseywww.cunj.com4.7(4363)Help millions make the right choiceHelp millions make the right choiceShare your experience on Trustpilot, where reviews make a difference.Login or sign upBest in Travel Insurance CompanySee moreAARDYaardy.com4.9(42106)TripInsure101tripinsure101.com4.9(3279)MexiPass International Insurance Serviceswww.mexipass.com4.9(1903)Travel Defenderstraveldefenders.com4.9(1772)We’re TrustpilotWe’re TrustpilotWe’re a review platform that’s open to everyone. Our vision is to become the universal symbol of trust — by empowering people to shop with confidence, and helping companies improve.What we doOur new Trust Report has landed!Find out which actions we’ve taken to protect you and promote trust on our platform.Take a lookRecent reviewsEmilioNordVPN is a SCAM.  DO NOT use their service, and DEFINITELY DO NOT RENEW if you are already a customer.  Their business practices prove that they HATE their repeat customers.  They make it seem like they\'re giving you a deal and as soon as they gain your trust, they DRAMATICALLY OVERCHARGE you when your service renews automatically.  You need to watch them with a microscope if you want to avoid being charged ALMOST DOUBLE for their services.  If you want to save time and a lot of headaches, JUST USE ANOTHER SERVICE.\n\nI started with NordVPN three years ago before it became a total scam.  Before, it was a pretty good VPN option with a fair price and quality services.  In 2022 I purchased a subscription which was set to be automatically renewed the year after.  Before my renewal I got an email from NordVPN offering two years for under 100 dollars (I think it was 90 dollars).  This was a great price so I was very happy with it, until the next year (mind you the original package was sold to me as a TWO-year package, NOT a ONE year package) when I was charged $168 USD to renew for that year.  I actually did not even notice this until the next year in November 2025, when I was being charged again 168 dollars for the same package offered on their website for their Threat Protection Pro package which their website shows is valued at 97.35 dollars (this is without any discount or promotion, just the raw price on their website).  I tried to contact NordVPN by sending multiple emails asking about this.  I have an extension that shows when recievers view my emails, so I know that they recieved and read my emails about this issue.  I got ABSOLUTELY NO REPLY to any of my emails requesting help or clarification with this issue.  Customer support was also absolutely 0 help in solving this.  The company clearly does not care one bit whatsoever about their customers, and at this point their lack of response to this critical issue seems downright malicious.\n\nSo I called my credit card company.  At this point I was still giving NordVPN the benefit of the doubt and assuming that perhaps they had accidentally double-charged me so I asked that the charge be modified to reflect half the value.  In other words, I made my payment to NordVPN around 80 dollars instead of the >160 dollars that they were charging me.  A week later (two months into my subsc ...
#  'Write a reviewCategoriesBlogLog inFor businessesFor businessesLog inWrite a reviewCategoriesBlog',
#  'Write a reviewCategoriesBlogLog inFor businesses',
#  'Write a reviewCategoriesBlogLog inFor businesses',
#  '',
#  '',
#  'For businessesLog inWrite a reviewCategoriesBlog',
#  '',
#  'For businessesLog inWrite a reviewCategoriesBlog',
#  'For businessesLog inWrite a reviewCategoriesBlog',
#  'For businessesLog inWrite a reviewCategoriesBlog',
#  'Log inWrite a reviewCategoriesBlog',
#  '',
#  '',
#  'Find a company you can trustDiscover, read, and write reviewsBought something recently?Write a reviewWhat are you looking for?See moreBankTravel Insurance CompanyCar DealerFurniture StoreJewelry StoreClothing StoreElectronics & TechnologyFitness and Nutrition ServicePet StoreEnergy SupplierReal Estate AgentsInsurance AgencyBedroom Furniture StoreActivewear StoreWomen\'s Clothing StoreMen\'s Clothing StoreBicycle StoreShoe StoreMortgage BrokerAppliance StoreCosmetics StoreElectronics StoreGarden CenterTravel AgencyLooking to grow your business?Strengthen your reputation with reviews on Trustpilot.Get startedBest in BankSee moreLendingClublendingclub.com4.7(9404)BankFivewww.bankfive.com4.7(5251)DuGood Credit Unionwww.dugood.org4.7(4429)Credit Union of New Jerseywww.cunj.com4.7(4363)Help millions make the right choiceHelp millions make the right choiceShare your experience on Trustpilot, where reviews make a difference.Login or sign upBest in Travel Insurance CompanySee moreAARDYaardy.com4.9(42106)TripInsure101tripinsure101.com4.9(3279)MexiPass International Insurance Serviceswww.mexipass.com4.9(1903)Travel Defenderstraveldefenders.com4.9(1772)We’re TrustpilotWe’re TrustpilotWe’re a review platform that’s open to everyone. Our vision is to become the universal symbol of trust — by empowering people to shop with confidence, and helping companies improve.What we doOur new Trust Report has landed!Find out which actions we’ve taken to protect you and promote trust on our platform.Take a lookRecent reviewsEmilioNordVPN is a SCAM.  DO NOT use their service, and DEFINITELY DO NOT RENEW if you are already a customer.  Their business practices prove that they HATE their repeat customers.  They make it seem like they\'re giving you a deal and as soon as they gain your trust, they DRAMATICALLY OVERCHARGE you when your service renews automatically.  You need to watch them with a microscope if you want to avoid being charged ALMOST DOUBLE for their services.  If you want to save time and a lot of headaches, JUST USE ANOTHER SERVICE.\n\nI started with NordVPN three years ago before it became a total scam.  Before, it was a pretty good VPN option with a fair price and quality services.  In 2022 I purchased a subscription which was set to be automatically renewed the year after.  Before my renewal I got an email from NordVPN offering two years for under 100 dollars (I think it was 90 dollars).  This was a great price so I was very happy with it, until the next year (mind you the original package was sold to me as a TWO-year package, NOT a ONE year package) when I was charged $168 USD to renew for that year.  I actually did not even notice this until the next year in November 2025, when I was being charged again 168 dollars for the same package offered on their website for their Threat Protection Pro package which their website shows is valued at 97.35 dollars (this is without any discount or promotion, just the raw price on their website).  I tried to contact NordVPN by sending multiple emails asking about this.  I have an extension that shows when recievers view my emails, so I know that they recieved and read my emails about this issue.  I got ABSOLUTELY NO REPLY to any of my emails requesting help or clarification with this issue.  Customer support was also absolutely 0 help in solving this.  The company clearly does not care one bit whatsoever about their customers, and at this point their lack of response to this critical issue seems downright malicious.\n\nSo I called my credit card company.  At this point I was still giving NordVPN the benefit of the doubt and assuming that perhaps they had accidentally double-charged me so I asked that the charge be modified to reflect half the value.  In other words, I made my payment to NordVPN around 80 dollars instead of the >160 dollars that they were charging me.  A week later (two months into my subscription) they are saying that my subscription has expired.  Absolutely no one will help me via e ...
#  'Find a company you can trustDiscover, read, and write reviewsBought something recently?Write a reviewWhat are you looking for?See moreBankTravel Insurance CompanyCar DealerFurniture StoreJewelry StoreClothing StoreElectronics & TechnologyFitness and Nutrition ServicePet StoreEnergy SupplierReal Estate AgentsInsurance AgencyBedroom Furniture StoreActivewear StoreWomen\'s Clothing StoreMen\'s Clothing StoreBicycle StoreShoe StoreMortgage BrokerAppliance StoreCosmetics StoreElectronics StoreGarden CenterTravel AgencyLooking to grow your business?Strengthen your reputation with reviews on Trustpilot.Get startedBest in BankSee moreLendingClublendingclub.com4.7(9404)BankFivewww.bankfive.com4.7(5251)DuGood Credit Unionwww.dugood.org4.7(4429)Credit Union of New Jerseywww.cunj.com4.7(4363)Help millions make the right choiceHelp millions make the right choiceShare your experience on Trustpilot, where reviews make a difference.Login or sign upBest in Travel Insurance CompanySee moreAARDYaardy.com4.9(42106)TripInsure101tripinsure101.com4.9(3279)MexiPass International Insurance Serviceswww.mexipass.com4.9(1903)Travel Defenderstraveldefenders.com4.9(1772)We’re TrustpilotWe’re TrustpilotWe’re a review platform that’s open to everyone. Our vision is to become the universal symbol of trust — by empowering people to shop with confidence, and helping companies improve.What we doOur new Trust Report has landed!Find out which actions we’ve taken to protect you and promote trust on our platform.Take a lookRecent reviewsEmilioNordVPN is a SCAM.  DO NOT use their service, and DEFINITELY DO NOT RENEW if you are already a customer.  Their business practices prove that they HATE their repeat customers.  They make it seem like they\'re giving you a deal and as soon as they gain your trust, they DRAMATICALLY OVERCHARGE you when your service renews automatically.  You need to watch them with a microscope if you want to avoid being charged ALMOST DOUBLE for their services.  If you want to save time and a lot of headaches, JUST USE ANOTHER SERVICE.\n\nI started with NordVPN three years ago before it became a total scam.  Before, it was a pretty good VPN option with a fair price and quality services.  In 2022 I purchased a subscription which was set to be automatically renewed the year after.  Before my renewal I got an email from NordVPN offering two years for under 100 dollars (I think it was 90 dollars).  This was a great price so I was very happy with it, until the next year (mind you the original package was sold to me as a TWO-year package, NOT a ONE year package) when I was charged $168 USD to renew for that year.  I actually did not even notice this until the next year in November 2025, when I was being charged again 168 dollars for the same package offered on their website for their Threat Protection Pro package which their website shows is valued at 97.35 dollars (this is without any discount or promotion, just the raw price on their website).  I tried to contact NordVPN by sending multiple emails asking about this.  I have an extension that shows when recievers view my emails, so I know that they recieved and read my emails about this issue.  I got ABSOLUTELY NO REPLY to any of my emails requesting help or clarification with this issue.  Customer support was also absolutely 0 help in solving this.  The company clearly does not care one bit whatsoever about their customers, and at this point their lack of response to this critical issue seems downright malicious.\n\nSo I called my credit card company.  At this point I was still giving NordVPN the benefit of the doubt and assuming that perhaps they had accidentally double-charged me so I asked that the charge be modified to reflect half the value.  In other words, I made my payment to NordVPN around 80 dollars instead of the >160 dollars that they were charging me.  A week later (two months into my subscription) they are saying that my subscription has expired.  Absolutely no one will help me via e ...
#  'Find a company you can trustDiscover, read, and write reviews',
#  'Find a company you can trustDiscover, read, and write reviews',
#  'Find a company you can trustDiscover, read, and write reviews',
#  'Find a company you can trustDiscover, read, and write reviews',
#  '',
#  '',
#  '',
#  '',
#  'Bought something recently?Write a review',
#  '',
#  'Bought something recently?Write a review',
#  'Write a review',
#  '',
#  '',
#  'What are you looking for?See more',
#  'See more',
#  "BankTravel Insurance CompanyCar DealerFurniture StoreJewelry StoreClothing StoreElectronics & TechnologyFitness and Nutrition ServicePet StoreEnergy SupplierReal Estate AgentsInsurance AgencyBedroom Furniture StoreActivewear StoreWomen's Clothing StoreMen's Clothing StoreBicycle StoreShoe StoreMortgage BrokerAppliance StoreCosmetics StoreElectronics StoreGarden CenterTravel Agency",
#  'Bank',
#  '',
#  'Bank',
#  'Travel Insurance Company',
#  '',
#  'Travel Insurance Company',
#  'Car Dealer',
#  '',
#  'Car Dealer',
#  'Furniture Store',
#  '',
#  'Furniture Store',
#  'Jewelry Store',
#  '',
#  'Jewelry Store',
#  'Clothing Store',
#  '',
#  'Clothing Store',
#  'Electronics & Technology',
#  '',
#  'Electronics & Technology',
#  'Fitness and Nutrition Service',
#  '',
#  'Fitness and Nutrition Service',
#  'Pet Store',
#  '',
#  'Pet Store',
#  'Energy Supplier',
#  '',
#  'Energy Supplier',
#  'Real Estate Agents',
#  '',
#  'Real Estate Agents',
#  'Insurance Agency',
#  '',
#  'Insurance Agency',
#  'Bedroom Furniture Store',
#  '',
#  'Bedroom Furniture Store',
#  'Activewear Store',
#  '',
#  'Activewear Store',
#  "Women's Clothing Store",
#  '',
#  "Women's Clothing Store",
#  "Men's Clothing Store",
#  '',
#  "Men's Clothing Store",
#  'Bicycle Store',
#  '',
#  'Bicycle Store',
#  'Shoe Store',
#  '',
#  'Shoe Store',
#  'Mortgage Broker',
#  '',
#  'Mortgage Broker',
#  'Appliance Store',
#  '',
#  'Appliance Store',
#  'Cosmetics Store',
#  '',
#  'Cosmetics Store',
#  'Electronics Store',
#  '',
#  'Electronics Store',
#  'Garden Center',
#  '',
#  'Garden Center',
#  'Travel Agency',
#  '',
#  'Travel Agency',
#  '',
#  'Looking to grow your business?Strengthen your reputation with reviews on Trustpilot.Get started',
#  '',
#  'Looking to grow your business?Strengthen your reputation with reviews on Trustpilot.Get started',
#  'Looking to grow your business?Strengthen your reputation with reviews on Trustpilot.',
#  'Best in BankSee moreLendingClublendingclub.com4.7(9404)BankFivewww.bankfive.com4.7(5251)DuGood Credit Unionwww.dugood.org4.7(4429)Credit Union of New Jerseywww.cunj.com4.7(4363)',
#  'Best in BankSee more',
#  'Best in Bank',
#  'See more',
#  'LendingClublendingclub.com4.7(9404)BankFivewww.bankfive.com4.7(5251)DuGood Credit Unionwww.dugood.org4.7(4429)Credit Union of New Jerseywww.cunj.com4.7(4363)',
#  'LendingClublendingclub.com4.7(9404)',
#  'LendingClublendingclub.com4.7(9404)',
#  '',
#  '',
#  '4.7(9404)',
#  '',
#  'BankFivewww.bankfive.com4.7(5251)',
#  'BankFivewww.bankfive.com4.7(5251)',
#  '',
#  '',
#  '4.7(5251)',
#  '',
#  'DuGood Credit Unionwww.dugood.org4.7(4429)',
#  'DuGood Credit Unionwww.dugood.org4.7(4429)',
#  '',
#  '',
#  '4.7(4429)',
#  '',
#  'Credit Union of New Jerseywww.cunj.com4.7(4363)',
#  'Credit Union of New Jerseywww.cunj.com4.7(4363)',
#  '',
#  '',
#  '4.7(4363)',
#  '',
#  'Help millions make the right choiceHelp millions make the right choiceShare your experience on Trustpilot, where reviews make a difference.Login or sign up',
#  'Help millions make the right choiceHelp millions make the right choiceShare your experience on Trustpilot, where reviews make a difference.Login or sign up',
#  'Login or sign up',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Best in Travel Insurance CompanySee moreAARDYaardy.com4.9(42106)TripInsure101tripinsure101.com4.9(3279)MexiPass International Insurance Serviceswww.mexipass.com4.9(1903)Travel Defenderstraveldefenders.com4.9(1772)',
#  'Best in Travel Insurance CompanySee more',
#  'Best in Travel Insurance Company',
#  'See more',
#  'AARDYaardy.com4.9(42106)TripInsure101tripinsure101.com4.9(3279)MexiPass International Insurance Serviceswww.mexipass.com4.9(1903)Travel Defenderstraveldefenders.com4.9(1772)',
#  'AARDYaardy.com4.9(42106)',
#  'AARDYaardy.com4.9(42106)',
#  '',
#  '',
#  '4.9(42106)',
#  '',
#  'TripInsure101tripinsure101.com4.9(3279)',
#  'TripInsure101tripinsure101.com4.9(3279)',
#  '',
#  '',
#  '4.9(3279)',
#  '',
#  'MexiPass International Insurance Serviceswww.mexipass.com4.9(1903)',
#  'MexiPass International Insurance Serviceswww.mexipass.com4.9(1903)',
#  '',
#  '',
#  '4.9(1903)',
#  '',
#  'Travel Defenderstraveldefenders.com4.9(1772)',
#  'Travel Defenderstraveldefenders.com4.9(1772)',
#  '',
#  '',
#  '4.9(1772)',
#  '',
#  'We’re TrustpilotWe’re TrustpilotWe’re a review platform that’s open to everyone. Our vision is to become the universal symbol of trust — by empowering people to shop with confidence, and helping companies improve.What we doOur new Trust Report has landed!Find out which actions we’ve taken to protect you and promote trust on our platform.Take a look',
#  'We’re TrustpilotWe’re TrustpilotWe’re a review platform that’s open to everyone. Our vision is to become the universal symbol of trust — by empowering people to shop with confidence, and helping companies improve.What we do',
#  'What we do',
#  'Our new Trust Report has landed!Find out which actions we’ve taken to protect you and promote trust on our platform.Take a look',
#  'Our new Trust Report has landed!Find out which actions we’ve taken to protect you and promote trust on our platform.Take a look',
#  'Our new Trust Report has landed!Find out which actions we’ve taken to protect you and promote trust on our platform.Take a look',
#  'Recent reviewsEmilioNordVPN is a SCAM.  DO NOT use their service, and DEFINITELY DO NOT RENEW if you are already a customer.  Their business practices prove that they HATE their repeat customers.  They make it seem like they\'re giving you a deal and as soon as they gain your trust, they DRAMATICALLY OVERCHARGE you when your service renews automatically.  You need to watch them with a microscope if you want to avoid being charged ALMOST DOUBLE for their services.  If you want to save time and a lot of headaches, JUST USE ANOTHER SERVICE.\n\nI started with NordVPN three years ago before it became a total scam.  Before, it was a pretty good VPN option with a fair price and quality services.  In 2022 I purchased a subscription which was set to be automatically renewed the year after.  Before my renewal I got an email from NordVPN offering two years for under 100 dollars (I think it was 90 dollars).  This was a great price so I was very happy with it, until the next year (mind you the original package was sold to me as a TWO-year package, NOT a ONE year package) when I was charged $168 USD to renew for that year.  I actually did not even notice this until the next year in November 2025, when I was being charged again 168 dollars for the same package offered on their website for their Threat Protection Pro package which their website shows is valued at 97.35 dollars (this is without any discount or promotion, just the raw price on their website).  I tried to contact NordVPN by sending multiple emails asking about this.  I have an extension that shows when recievers view my emails, so I know that they recieved and read my emails about this issue.  I got ABSOLUTELY NO REPLY to any of my emails requesting help or clarification with this issue.  Customer support was also absolutely 0 help in solving this.  The company clearly does not care one bit whatsoever about their customers, and at this point their lack of response to this critical issue seems downright malicious.\n\nSo I called my credit card company.  At this point I was still giving NordVPN the benefit of the doubt and assuming that perhaps they had accidentally double-charged me so I asked that the charge be modified to reflect half the value.  In other words, I made my payment to NordVPN around 80 dollars instead of the >160 dollars that they were charging me.  A week later (two months into my subscription) they are saying that my subscription has expired.  Absolutely no one will help me via email or over the phone, so I will now have to call my credit card company back AGAIN and completely cancel the charge.  I have now wasted around 3 cumulative hours of my time trying to resolve this.  \n\nI also noticed after modifying the charge from NordVPN that my iPhone\'s WiFi and internet stopped working.  The last entity I expected to be responsible for this was NordVPN, but after spending an hour trying to diagnose my iPhone, I saw a tutorial that recommended disabling VPN services as a roubleshooting step.  Mind you, I HAD NOT USED NORDVPN ON THAT PHONE for probably over a year.  The application was simply installed on the phone and doing nothing.  After purging NordVPN\'s app from my phone completely, iPhone WiFi immediately started working perfectly.  Remember, I DID NOT HAVE THE VPN RUNNING when this took place.  SIMPLY HAVING THEIR APP ON MY PHONE made the WiFi stop working when they decided to suspend my service.  Due to the company\'s clear disdain for repeat customers, I suspect this may have somehow been set up intentionally as a way to punish people who dont want to let NordVPN rip them off (it happened a few days after I modified the charge, and I have NEVER had any issues with my iPhone\'s WiFi before that).  \n\nI am so furious over the overcharging that I forgot to mention the other serious issue with NordVPN - THEIR SERVICE SUCKS NOW.  When I started using Nord their servers were pretty much always working, everything could be easily managed from the terminal and ...
#  'Recent reviews',
#  'Recent reviews',
#  '',
#  'EmilioNordVPN is a SCAM.  DO NOT use their service, and DEFINITELY DO NOT RENEW if you are already a customer.  Their business practices prove that they HATE their repeat customers.  They make it seem like they\'re giving you a deal and as soon as they gain your trust, they DRAMATICALLY OVERCHARGE you when your service renews automatically.  You need to watch them with a microscope if you want to avoid being charged ALMOST DOUBLE for their services.  If you want to save time and a lot of headaches, JUST USE ANOTHER SERVICE.\n\nI started with NordVPN three years ago before it became a total scam.  Before, it was a pretty good VPN option with a fair price and quality services.  In 2022 I purchased a subscription which was set to be automatically renewed the year after.  Before my renewal I got an email from NordVPN offering two years for under 100 dollars (I think it was 90 dollars).  This was a great price so I was very happy with it, until the next year (mind you the original package was sold to me as a TWO-year package, NOT a ONE year package) when I was charged $168 USD to renew for that year.  I actually did not even notice this until the next year in November 2025, when I was being charged again 168 dollars for the same package offered on their website for their Threat Protection Pro package which their website shows is valued at 97.35 dollars (this is without any discount or promotion, just the raw price on their website).  I tried to contact NordVPN by sending multiple emails asking about this.  I have an extension that shows when recievers view my emails, so I know that they recieved and read my emails about this issue.  I got ABSOLUTELY NO REPLY to any of my emails requesting help or clarification with this issue.  Customer support was also absolutely 0 help in solving this.  The company clearly does not care one bit whatsoever about their customers, and at this point their lack of response to this critical issue seems downright malicious.\n\nSo I called my credit card company.  At this point I was still giving NordVPN the benefit of the doubt and assuming that perhaps they had accidentally double-charged me so I asked that the charge be modified to reflect half the value.  In other words, I made my payment to NordVPN around 80 dollars instead of the >160 dollars that they were charging me.  A week later (two months into my subscription) they are saying that my subscription has expired.  Absolutely no one will help me via email or over the phone, so I will now have to call my credit card company back AGAIN and completely cancel the charge.  I have now wasted around 3 cumulative hours of my time trying to resolve this.  \n\nI also noticed after modifying the charge from NordVPN that my iPhone\'s WiFi and internet stopped working.  The last entity I expected to be responsible for this was NordVPN, but after spending an hour trying to diagnose my iPhone, I saw a tutorial that recommended disabling VPN services as a roubleshooting step.  Mind you, I HAD NOT USED NORDVPN ON THAT PHONE for probably over a year.  The application was simply installed on the phone and doing nothing.  After purging NordVPN\'s app from my phone completely, iPhone WiFi immediately started working perfectly.  Remember, I DID NOT HAVE THE VPN RUNNING when this took place.  SIMPLY HAVING THEIR APP ON MY PHONE made the WiFi stop working when they decided to suspend my service.  Due to the company\'s clear disdain for repeat customers, I suspect this may have somehow been set up intentionally as a way to punish people who dont want to let NordVPN rip them off (it happened a few days after I modified the charge, and I have NEVER had any issues with my iPhone\'s WiFi before that).  \n\nI am so furious over the overcharging that I forgot to mention the other serious issue with NordVPN - THEIR SERVICE SUCKS NOW.  When I started using Nord their servers were pretty much always working, everything could be easily managed from the terminal and every once in ...
#  "EmilioNordVPN is a SCAM.  DO NOT use their service, and DEFINITELY DO NOT RENEW if you are already a customer.  Their business practices prove that they HATE their repeat customers.  They make it seem like they're giving you a deal and as soon as they gain your trust, they DRAMATICALLY OVERCHARGE you when your service renews automatically.  You need to watch them with a microscope if you want to avoid being charged ALMOST DOUBLE for their services.  If you want to save time and a lot of headaches, JUST USE ANOTHER SERVICE.\n\nI started with NordVPN three years ago before it became a total scam.  Before, it was a pretty good VPN option with a fair price and quality services.  In 2022 I purchased a subscription which was set to be automatically renewed the year after.  Before my renewal I got an email from NordVPN offering two years for under 100 dollars (I think it was 90 dollars).  This was a great price so I was very happy with it, until the next year (mind you the original package was sold to me as a TWO-year package, NOT a ONE year package) when I was charged $168 USD to renew for that year.  I actually did not even notice this until the next year in November 2025, when I was being charged again 168 dollars for the same package offered on their website for their Threat Protection Pro package which their website shows is valued at 97.35 dollars (this is without any discount or promotion, just the raw price on their website).  I tried to contact NordVPN by sending multiple emails asking about this.  I have an extension that shows when recievers view my emails, so I know that they recieved and read my emails about this issue.  I got ABSOLUTELY NO REPLY to any of my emails requesting help or clarification with this issue.  Customer support was also absolutely 0 help in solving this.  The company clearly does not care one bit whatsoever about their customers, and at this point their lack of response to this critical issue seems downright malicious.\n\nSo I called my credit card company.  At this point I was still giving NordVPN the benefit of the doubt and assuming that perhaps they had accidentally double-charged me so I asked that the charge be modified to reflect half the value.  In other words, I made my payment to NordVPN around 80 dollars instead of the >160 dollars that they were charging me.  A week later (two months into my subscription) they are saying that my subscription has expired.  Absolutely no one will help me via email or over the phone, so I will now have to call my credit card company back AGAIN and completely cancel the charge.  I have now wasted around 3 cumulative hours of my time trying to resolve this.  \n\nI also noticed after modifying the charge from NordVPN that my iPhone's WiFi and internet stopped working.  The last entity I expected to be responsible for this was NordVPN, but after spending an hour trying to diagnose my iPhone, I saw a tutorial that recommended disabling VPN services as a roubleshooting step.  Mind you, I HAD NOT USED NORDVPN ON THAT PHONE for probably over a year.  The application was simply installed on the phone and doing nothing.  After purging NordVPN's app from my phone completely, iPhone WiFi immediately started working perfectly.  Remember, I DID NOT HAVE THE VPN RUNNING when this took place.  SIMPLY HAVING THEIR APP ON MY PHONE made the WiFi stop working when they decided to suspend my service.  Due to the company's clear disdain for repeat customers, I suspect this may have somehow been set up intentionally as a way to punish people who dont want to let NordVPN rip them off (it happened a few days after I modified the charge, and I have NEVER had any issues with my iPhone's WiFi before that).  \n\nI am so furious over the overcharging that I forgot to mention the other serious issue with NordVPN - THEIR SERVICE SUCKS NOW.  When I started using Nord their servers were pretty much always working, everything could be easily managed from the terminal and every once in a wh ...
#  "EmilioNordVPN is a SCAM.  DO NOT use their service, and DEFINITELY DO NOT RENEW if you are already a customer.  Their business practices prove that they HATE their repeat customers.  They make it seem like they're giving you a deal and as soon as they gain your trust, they DRAMATICALLY OVERCHARGE you when your service renews automatically.  You need to watch them with a microscope if you want to avoid being charged ALMOST DOUBLE for their services.  If you want to save time and a lot of headaches, JUST USE ANOTHER SERVICE.\n\nI started with NordVPN three years ago before it became a total scam.  Before, it was a pretty good VPN option with a fair price and quality services.  In 2022 I purchased a subscription which was set to be automatically renewed the year after.  Before my renewal I got an email from NordVPN offering two years for under 100 dollars (I think it was 90 dollars).  This was a great price so I was very happy with it, until the next year (mind you the original package was sold to me as a TWO-year package, NOT a ONE year package) when I was charged $168 USD to renew for that year.  I actually did not even notice this until the next year in November 2025, when I was being charged again 168 dollars for the same package offered on their website for their Threat Protection Pro package which their website shows is valued at 97.35 dollars (this is without any discount or promotion, just the raw price on their website).  I tried to contact NordVPN by sending multiple emails asking about this.  I have an extension that shows when recievers view my emails, so I know that they recieved and read my emails about this issue.  I got ABSOLUTELY NO REPLY to any of my emails requesting help or clarification with this issue.  Customer support was also absolutely 0 help in solving this.  The company clearly does not care one bit whatsoever about their customers, and at this point their lack of response to this critical issue seems downright malicious.\n\nSo I called my credit card company.  At this point I was still giving NordVPN the benefit of the doubt and assuming that perhaps they had accidentally double-charged me so I asked that the charge be modified to reflect half the value.  In other words, I made my payment to NordVPN around 80 dollars instead of the >160 dollars that they were charging me.  A week later (two months into my subscription) they are saying that my subscription has expired.  Absolutely no one will help me via email or over the phone, so I will now have to call my credit card company back AGAIN and completely cancel the charge.  I have now wasted around 3 cumulative hours of my time trying to resolve this.  \n\nI also noticed after modifying the charge from NordVPN that my iPhone's WiFi and internet stopped working.  The last entity I expected to be responsible for this was NordVPN, but after spending an hour trying to diagnose my iPhone, I saw a tutorial that recommended disabling VPN services as a roubleshooting step.  Mind you, I HAD NOT USED NORDVPN ON THAT PHONE for probably over a year.  The application was simply installed on the phone and doing nothing.  After purging NordVPN's app from my phone completely, iPhone WiFi immediately started working perfectly.  Remember, I DID NOT HAVE THE VPN RUNNING when this took place.  SIMPLY HAVING THEIR APP ON MY PHONE made the WiFi stop working when they decided to suspend my service.  Due to the company's clear disdain for repeat customers, I suspect this may have somehow been set up intentionally as a way to punish people who dont want to let NordVPN rip them off (it happened a few days after I modified the charge, and I have NEVER had any issues with my iPhone's WiFi before that).  \n\nI am so furious over the overcharging that I forgot to mention the other serious issue with NordVPN - THEIR SERVICE SUCKS NOW.  When I started using Nord their servers were pretty much always working, everything could be easily managed from the terminal and every once in a wh ...
#  'Emilio',
#  '',
#  '',
#  'Emilio',
#  "NordVPN is a SCAM.  DO NOT use their service, and DEFINITELY DO NOT RENEW if you are already a customer.  Their business practices prove that they HATE their repeat customers.  They make it seem like they're giving you a deal and as soon as they gain your trust, they DRAMATICALLY OVERCHARGE you when your service renews automatically.  You need to watch them with a microscope if you want to avoid being charged ALMOST DOUBLE for their services.  If you want to save time and a lot of headaches, JUST USE ANOTHER SERVICE.\n\nI started with NordVPN three years ago before it became a total scam.  Before, it was a pretty good VPN option with a fair price and quality services.  In 2022 I purchased a subscription which was set to be automatically renewed the year after.  Before my renewal I got an email from NordVPN offering two years for under 100 dollars (I think it was 90 dollars).  This was a great price so I was very happy with it, until the next year (mind you the original package was sold to me as a TWO-year package, NOT a ONE year package) when I was charged $168 USD to renew for that year.  I actually did not even notice this until the next year in November 2025, when I was being charged again 168 dollars for the same package offered on their website for their Threat Protection Pro package which their website shows is valued at 97.35 dollars (this is without any discount or promotion, just the raw price on their website).  I tried to contact NordVPN by sending multiple emails asking about this.  I have an extension that shows when recievers view my emails, so I know that they recieved and read my emails about this issue.  I got ABSOLUTELY NO REPLY to any of my emails requesting help or clarification with this issue.  Customer support was also absolutely 0 help in solving this.  The company clearly does not care one bit whatsoever about their customers, and at this point their lack of response to this critical issue seems downright malicious.\n\nSo I called my credit card company.  At this point I was still giving NordVPN the benefit of the doubt and assuming that perhaps they had accidentally double-charged me so I asked that the charge be modified to reflect half the value.  In other words, I made my payment to NordVPN around 80 dollars instead of the >160 dollars that they were charging me.  A week later (two months into my subscription) they are saying that my subscription has expired.  Absolutely no one will help me via email or over the phone, so I will now have to call my credit card company back AGAIN and completely cancel the charge.  I have now wasted around 3 cumulative hours of my time trying to resolve this.  \n\nI also noticed after modifying the charge from NordVPN that my iPhone's WiFi and internet stopped working.  The last entity I expected to be responsible for this was NordVPN, but after spending an hour trying to diagnose my iPhone, I saw a tutorial that recommended disabling VPN services as a roubleshooting step.  Mind you, I HAD NOT USED NORDVPN ON THAT PHONE for probably over a year.  The application was simply installed on the phone and doing nothing.  After purging NordVPN's app from my phone completely, iPhone WiFi immediately started working perfectly.  Remember, I DID NOT HAVE THE VPN RUNNING when this took place.  SIMPLY HAVING THEIR APP ON MY PHONE made the WiFi stop working when they decided to suspend my service.  Due to the company's clear disdain for repeat customers, I suspect this may have somehow been set up intentionally as a way to punish people who dont want to let NordVPN rip them off (it happened a few days after I modified the charge, and I have NEVER had any issues with my iPhone's WiFi before that).  \n\nI am so furious over the overcharging that I forgot to mention the other serious issue with NordVPN - THEIR SERVICE SUCKS NOW.  When I started using Nord their servers were pretty much always working, everything could be easily managed from the terminal and every once in a while yo ...
#  'NordVPNnordvpn.com',
#  '',
#  'NordVPNnordvpn.com',
#  "B.D. McAteerI do leatherworking as a side hobby so I can speak with some authority on the matter. This Maveric Jacket is NOT what they are advertising. I would not be surprised if they stole the image and made their own because the cuts are all wrong. The presentation was good and so was customer service, but the moment you say the word refund, they ghosted me. Cool, so you won't stand by your product or even discuss with me what may be the issue. Maybe I don't understand something about the product. Okay, help me understand then. Nope, none of that. I get this boxy shapeless jacket meant for a guy with a belly far larger than my own and you say nothing. My advice? Buy Lucky's Brand leatherjacket. Mine is a decade old and has looked great the whole time. Had to stretch it though because I put on good weight. This Maveric is a huge ugly disappointment. I waited a while for a review to give them the benefit of the doubt. Nothing? Here we are now. Don't buy Hawk and Bull.Hawk & Bullhawkbull.com",
#  'B.D. McAteer',
#  '',
#  '',
#  'B.D. McAteer',
# ...
#  'Web Designs Glowwebdesignsglow.com',
#  '',
#  'Web Designs Glowwebdesignsglow.com',
#  'Anastasiia TaratukhinaI just want to write about how comfortable this place is for me personally. I have poor English and am always nervous before such meetings, but the whole team is very friendly and understanding.Optical Express UKwww.opticalexpress.co.uk',
#  'Anastasiia Taratukhina',
#  '',
#  '',
#  'Anastasiia Taratukhina',
#  'I just want to write about how comfortable this place is for me personally. I have poor English and am always nervous before such meetings, but the whole team is very friendly and understanding.',
#  'Optical Express UKwww.opticalexpress.co.uk',
#  '',
#  'Optical Express UKwww.opticalexpress.co.uk',
#  'AlexandraClaire DadeBrilliant experience with Owen today on the fun, he was friendly, informative and understanding of the fact I had two small children to look after when on the phone too.Red.co.ukred.co.ukDianeWebsite easy to maneuver. OSHA came sooner than expected. The postage was quite a bit, but I trust these products so I was willing to pay it.Mountain Rose Herbswww.mountainroseherbs.com',
#  'AlexandraClaire DadeBrilliant experience with Owen today on the fun, he was friendly, informative and understanding of the fact I had two small children to look after when on the phone too.Red.co.ukred.co.uk',
#  'AlexandraClaire Dade',
#  '',
#  '',
#  'AlexandraClaire Dade',
#  'Brilliant experience with Owen today on the fun, he was friendly, informative and understanding of the fact I had two small children to look after when on the phone too.',
#  'Red.co.ukred.co.uk',
#  '',
#  'Red.co.ukred.co.uk',
#  'DianeWebsite easy to maneuver. OSHA came sooner than expected. The postage was quite a bit, but I trust these products so I was willing to pay it.Mountain Rose Herbswww.mountainroseherbs.com',
#  'Diane',
#  '',
#  '',
#  'Diane',
#  'Website easy to maneuver. OSHA came sooner than expected. The postage was quite a bit, but I trust these products so I was willing to pay it.',
#  'Mountain Rose Herbswww.mountainroseherbs.com',
#  '',
#  'Mountain Rose Herbswww.mountainroseherbs.com',
#  "Jake WinterGot 20 beers across 2 boxes and all were fantastic. Only cancelled as I needed the money and that cancellation was made very easy by Dani.Beer52www.beer52.comMarie PaughThey do not answer emails..I've sent several trying to get info on my order and have not gotten an answer yet..feel scammed!!!!Avenlyavenly.de",
#  'Jake WinterGot 20 beers across 2 boxes and all were fantastic. Only cancelled as I needed the money and that cancellation was made very easy by Dani.Beer52www.beer52.com',
#  'Jake Winter',
#  '',
#  '',
#  'Jake Winter',
#  'Got 20 beers across 2 boxes and all were fantastic. Only cancelled as I needed the money and that cancellation was made very easy by Dani.',
#  'Beer52www.beer52.com',
#  '',
#  'Beer52www.beer52.com',
#  "Marie PaughThey do not answer emails..I've sent several trying to get info on my order and have not gotten an answer yet..feel scammed!!!!Avenlyavenly.de",
#  'Marie Paugh',
#  '',
#  '',
#  'Marie Paugh',
#  "They do not answer emails..I've sent several trying to get info on my order and have not gotten an answer yet..feel scammed!!!!",
#  'Avenlyavenly.de',
#  '',
#  'Avenlyavenly.de',
#  'Srinibas PadhiRequest for replacement but no response from the company. Sent several emails but no reply.  Call centre contact no is fake.Spaces Lifewww.spaceslife.comHelen BriceThis is well worth the introductory offer and subscription. It’s a superior taste - I choose the darkest roast. Very happy✨Wonky Coffeewonkycoffee.com',
#  'Srinibas PadhiRequest for replacement but no response from the company. Sent several emails but no reply.  Call centre contact no is fake.Spaces Lifewww.spaceslife.com',
#  'Srinibas Padhi',
#  '',
#  '',
#  'Srinibas Padhi',
#  'Request for replacement but no response from the company. Sent several emails but no reply.  Call centre contact no is fake.',
#  'Spaces Lifewww.spaceslife.com',
#  '',
#  'Spaces Lifewww.spaceslife.com',
#  'Helen BriceThis is well worth the introductory offer and subscription. It’s a superior taste - I choose the darkest roast. Very happy✨Wonky Coffeewonkycoffee.com',
#  'Helen Brice',
#  '',
#  '',
#  'Helen Brice',
#  'This is well worth the introductory offer and subscription. It’s a superior taste - I choose the darkest roast. Very happy✨',
#  'Wonky Coffeewonkycoffee.com',
#  '',
#  'Wonky Coffeewonkycoffee.com',
#  'john twittyHi the refund was well appreciated \nWith Christmas behind us and s little payment to top us up \nThank you JoE.ON Next Energy Ltdeonnext.comDaniel JoseThis agent is grate, they have the best prices and they often give so many credits and discount coupons.Superbuy Shoppingwww.superbuy.com',
#  'john twittyHi the refund was well appreciated \nWith Christmas behind us and s little payment to top us up \nThank you JoE.ON Next Energy Ltdeonnext.com',
#  'john twitty',
#  '',
#  '',
#  'john twitty',
#  'Hi the refund was well appreciated \nWith Christmas behind us and s little payment to top us up \nThank you Jo',
#  'E.ON Next Energy Ltdeonnext.com',
#  '',
#  'E.ON Next Energy Ltdeonnext.com',
#  'Daniel JoseThis agent is grate, they have the best prices and they often give so many credits and discount coupons.Superbuy Shoppingwww.superbuy.com',
#  'Daniel Jose',
#  '',
#  '',
#  'Daniel Jose',
#  'This agent is grate, they have the best prices and they often give so many credits and discount coupons.',
#  'Superbuy Shoppingwww.superbuy.com',
#  '',
#  'Superbuy Shoppingwww.superbuy.com',
#  'Anna CizmarovaWe love CURRYS. Always good and quality products. Fast delivery, never problem. \n\nHighly recommend itCurryswww.currys.co.ukvirgin boysThey are good lot struggled lot of fail 1st payout I received thank you fundingticks team 😍😍😍FundingTicksfundingticks.com',
#  'Anna CizmarovaWe love CURRYS. Always good and quality products. Fast delivery, never problem. \n\nHighly recommend itCurryswww.currys.co.uk',
#  'Anna Cizmarova',
#  '',
#  '',
#  'Anna Cizmarova',
#  'We love CURRYS. Always good and quality products. Fast delivery, never problem. \n\nHighly recommend it',
#  'Curryswww.currys.co.uk',
#  '',
#  'Curryswww.currys.co.uk',
#  'virgin boysThey are good lot struggled lot of fail 1st payout I received thank you fundingticks team 😍😍😍FundingTicksfundingticks.com',
#  'virgin boys',
#  '',
#  '',
#  'virgin boys',
#  'They are good lot struggled lot of fail 1st payout I received thank you fundingticks team 😍😍😍',
#  'FundingTicksfundingticks.com',
#  '',
#  'FundingTicksfundingticks.com',
#  'Colin RileyOrdered 2 Motorola fast chargers. Quick delivery, excellent value. Cannot fault GB mobile.GB Mobilegbmobile.co.ukJames SeddonMark was very good to deal with and was very knowledgeable. \n\nWould definitely recommendAcorn Business Centreacorn-businesscentre.co.uk',
#  'Colin RileyOrdered 2 Motorola fast chargers. Quick delivery, excellent value. Cannot fault GB mobile.GB Mobilegbmobile.co.uk',
#  'Colin Riley',
#  '',
#  '',
#  'Colin Riley',
#  'Ordered 2 Motorola fast chargers. Quick delivery, excellent value. Cannot fault GB mobile.',
#  'GB Mobilegbmobile.co.uk',
#  '',
#  'GB Mobilegbmobile.co.uk',
#  'James SeddonMark was very good to deal with and was very knowledgeable. \n\nWould definitely recommendAcorn Business Centreacorn-businesscentre.co.uk',
#  'James Seddon',
#  '',
#  '',
#  'James Seddon',
#  'Mark was very good to deal with and was very knowledgeable. \n\nWould definitely recommend',
#  'Acorn Business Centreacorn-businesscentre.co.uk',
#  '',
#  'Acorn Business Centreacorn-businesscentre.co.uk',
#  'Manuela CostaGreat service!!\nWonderful packaging to ensure goods are received in perfect orderPortugal Vineyardswww.portugalvineyards.comDebbie RockwellI love the makeup feels like you have nothing on and the coverage it great.Try Hushtry-hush.com',
#  'Manuela CostaGreat service!!\nWonderful packaging to ensure goods are received in perfect orderPortugal Vineyardswww.portugalvineyards.com',
#  'Manuela Costa',
#  '',
#  '',
#  'Manuela Costa',
#  'Great service!!\nWonderful packaging to ensure goods are received in perfect order',
#  'Portugal Vineyardswww.portugalvineyards.com',
#  '',
#  'Portugal Vineyardswww.portugalvineyards.com',
#  'Debbie RockwellI love the makeup feels like you have nothing on and the coverage it great.Try Hushtry-hush.com',
#  'Debbie Rockwell',
#  '',
#  '',
#  'Debbie Rockwell',
#  'I love the makeup feels like you have nothing on and the coverage it great.',
#  'Try Hushtry-hush.com',
#  '',
#  'Try Hushtry-hush.com',
#  'Eden Inckle-sharpeCara and Jean-luc were very helpful finding me the right jacket, 5 star! :)GO Outdoorswww.gooutdoors.co.ukK ParkerSo far so good, too new to leave more of a review. B+ for sure thoughDaVincis Golddavincisgold.com',
#  'Eden Inckle-sharpeCara and Jean-luc were very helpful finding me the right jacket, 5 star! :)GO Outdoorswww.gooutdoors.co.uk',
#  'Eden Inckle-sharpe',
#  '',
#  '',
#  'Eden Inckle-sharpe',
#  'Cara and Jean-luc were very helpful finding me the right jacket, 5 star! :)',
#  'GO Outdoorswww.gooutdoors.co.uk',
#  '',
#  'GO Outdoorswww.gooutdoors.co.uk',
#  'K ParkerSo far so good, too new to leave more of a review. B+ for sure thoughDaVincis Golddavincisgold.com',
#  'K Parker',
#  '',
#  '',
#  'K Parker',
#  'So far so good, too new to leave more of a review. B+ for sure though',
#  'DaVincis Golddavincisgold.com',
#  '',
#  'DaVincis Golddavincisgold.com',
#  'Dori VargaNice and clean and the product was delivered as promised on timeNumber Artistnumberartist.comEmaThe app is very useful, l am using the app and i like very muchDragonia Casinonexusgold.click',
#  'Dori VargaNice and clean and the product was delivered as promised on timeNumber Artistnumberartist.com',
#  'Dori Varga',
#  '',
#  '',
#  'Dori Varga',
#  'Nice and clean and the product was delivered as promised on time',
#  'Number Artistnumberartist.com',
#  '',
#  'Number Artistnumberartist.com',
#  'EmaThe app is very useful, l am using the app and i like very muchDragonia Casinonexusgold.click',
#  'Ema',
#  '',
#  '',
#  'Ema',
#  'The app is very useful, l am using the app and i like very much',
#  'Dragonia Casinonexusgold.click',
#  '',
#  'Dragonia Casinonexusgold.click',
#  "Florensa PrabaharanFantastic service and hospitality really they are very kindBumperbumper.coConstantin HartmannIt's very good, I thought I was talking to a real person.Get Leanget-lean.app",
#  'Florensa PrabaharanFantastic service and hospitality really they are very kindBumperbumper.co',
#  'Florensa Prabaharan',
#  '',
#  '',
#  'Florensa Prabaharan',
#  'Fantastic service and hospitality really they are very kind',
#  'Bumperbumper.co',
#  '',
#  'Bumperbumper.co',
#  "Constantin HartmannIt's very good, I thought I was talking to a real person.Get Leanget-lean.app",
#  'Constantin Hartmann',
#  '',
#  '',
#  'Constantin Hartmann',
#  "It's very good, I thought I was talking to a real person.",
#  'Get Leanget-lean.app',
#  '',
#  'Get Leanget-lean.app',
#  'Facundo Ponce de LeónVery good\nFast\nFair\nNice and competent employeesLocauto Grouplocautorent.comEvie Uebersax-BlincoePerfume lasts agessss, and smells amazing!!!The Essence Vaultwww.theessencevault.co.uk',
#  'Facundo Ponce de LeónVery good\nFast\nFair\nNice and competent employeesLocauto Grouplocautorent.com',
#  'Facundo Ponce de León',
#  '',
#  '',
#  'Facundo Ponce de León',
#  'Very good\nFast\nFair\nNice and competent employees',
#  'Locauto Grouplocautorent.com',
#  '',
#  'Locauto Grouplocautorent.com',
#  'Evie Uebersax-BlincoePerfume lasts agessss, and smells amazing!!!The Essence Vaultwww.theessencevault.co.uk',
#  'Evie Uebersax-Blincoe',
#  '',
#  '',
#  'Evie Uebersax-Blincoe',
#  'Perfume lasts agessss, and smells amazing!!!',
#  'The Essence Vaultwww.theessencevault.co.uk',
#  '',
#  'The Essence Vaultwww.theessencevault.co.uk',
#  "Joe BuffordAll you do is take people's money poor rtpChancedchanced.comGeorge McpheeGreat value cards well worth the priceThe Card Barnthecardbarn.co.uk",
#  "Joe BuffordAll you do is take people's money poor rtpChancedchanced.com",
#  'Joe Bufford',
#  '',
#  '',
#  'Joe Bufford',
#  "All you do is take people's money poor rtp",
#  'Chancedchanced.com',
#  '',
#  'Chancedchanced.com',
#  'George McpheeGreat value cards well worth the priceThe Card Barnthecardbarn.co.uk',
#  'George Mcphee',
#  '',
#  '',
#  'George Mcphee',
#  'Great value cards well worth the price',
#  'The Card Barnthecardbarn.co.uk',
#  '',
#  'The Card Barnthecardbarn.co.uk',
#  'Denise GoyetteOrdered, shipped, arrived quickly!!Fame Marketing and Trading LLCixirpro.comEliza AhmadThe hoodie looks so nicePinkpalmpuffpinkpalmpuff.com',
#  'Denise GoyetteOrdered, shipped, arrived quickly!!Fame Marketing and Trading LLCixirpro.com',
#  'Denise Goyette',
#  '',
#  '',
#  'Denise Goyette',
#  'Ordered, shipped, arrived quickly!!',
#  'Fame Marketing and Trading LLCixirpro.com',
#  '',
#  'Fame Marketing and Trading LLCixirpro.com',
#  'Eliza AhmadThe hoodie looks so nicePinkpalmpuffpinkpalmpuff.com',
#  'Eliza Ahmad',
#  '',
#  '',
#  'Eliza Ahmad',
#  'The hoodie looks so nice',
#  'Pinkpalmpuffpinkpalmpuff.com',
#  '',
#  'Pinkpalmpuffpinkpalmpuff.com',
#  'Loi Martinvery good, I enjoyed itAlisonalison.comjorge armandoGood and easy tanks youMyimagemyimage.io',
#  'Loi Martinvery good, I enjoyed itAlisonalison.com',
#  'Loi Martin',
#  '',
#  '',
#  'Loi Martin',
#  'very good, I enjoyed it',
#  'Alisonalison.com',
#  '',
#  'Alisonalison.com',
#  'jorge armandoGood and easy tanks youMyimagemyimage.io',
#  'jorge armando',
#  '',
#  '',
#  'jorge armando',
#  'Good and easy tanks you',
#  'Myimagemyimage.io',
#  '',
#  'Myimagemyimage.io',
#  'Christine HoltonVery easy to collect.InPost UKinpost.co.ukJán MinárikBest games foreverParadise8paradise8.com',
#  'Christine HoltonVery easy to collect.InPost UKinpost.co.uk',
#  'Christine Holton',
#  '',
#  '',
#  'Christine Holton',
#  'Very easy to collect.',
#  'InPost UKinpost.co.uk',
#  '',
#  'InPost UKinpost.co.uk',
#  'Ján MinárikBest games foreverParadise8paradise8.com',
#  'Ján Minárik',
#  '',
#  '',
#  'Ján Minárik',
#  'Best games forever',
#  'Paradise8paradise8.com',
#  '',
#  'Paradise8paradise8.com',
#  'Shop smarter with the Trustpilot appFind companies, read reviews, or write them—all while on the go.',
#  '',
#  '',
#  '',
#  '',
#  'Shop smarter with the Trustpilot appFind companies, read reviews, or write them—all while on the go.',
#  'Shop smarter with the Trustpilot app',
#  'Find companies, read reviews, or write them—all while on the go.',
#  '',
#  'are you human?',
#  'Choose countryUnited StatesDanmarkÖsterreichSchweizDeutschlandAustraliaCanadaUnited KingdomIrelandNew ZealandUnited StatesEspañaSuomiBelgiqueBelgiëFranceItalia日本NorgeNederlandPolskaBrasilPortugalSverigeAboutAbout usJobsContactBlogHow Trustpilot worksTrust ReportPressInvestor RelationsCommunityTrust in reviewsHelp CenterLog inSign upBusinessesTrustpilot BusinessProductsPlans & PricingBusiness LoginBlog for BusinessData SolutionsFollow us onLegalPrivacy PolicyTerms & ConditionsGuidelines for ReviewersSystem statusModern Slavery Statement© 2026 Trustpilot, Inc. All rights reserved.',
#  'Choose countryUnited StatesDanmarkÖsterreichSchweizDeutschlandAustraliaCanadaUnited KingdomIrelandNew ZealandUnited StatesEspañaSuomiBelgiqueBelgiëFranceItalia日本NorgeNederlandPolskaBrasilPortugalSverigeAboutAbout usJobsContactBlogHow Trustpilot worksTrust ReportPressInvestor RelationsCommunityTrust in reviewsHelp CenterLog inSign upBusinessesTrustpilot BusinessProductsPlans & PricingBusiness LoginBlog for BusinessData SolutionsFollow us onLegalPrivacy PolicyTerms & ConditionsGuidelines for ReviewersSystem statusModern Slavery Statement© 2026 Trustpilot, Inc. All rights reserved.',
#  '',
#  'United StatesDanmarkÖsterreichSchweizDeutschlandAustraliaCanadaUnited KingdomIrelandNew ZealandUnited StatesEspañaSuomiBelgiqueBelgiëFranceItalia日本NorgeNederlandPolskaBrasilPortugalSverige',
#  'United StatesDanmarkÖsterreichSchweizDeutschlandAustraliaCanadaUnited KingdomIrelandNew ZealandUnited StatesEspañaSuomiBelgiqueBelgiëFranceItalia日本NorgeNederlandPolskaBrasilPortugalSverige',
#  'LegalPrivacy PolicyTerms & ConditionsGuidelines for ReviewersSystem statusModern Slavery Statement© 2026 Trustpilot, Inc. All rights reserved.',
#  '© 2026 Trustpilot, Inc. All rights reserved.']

# %%
recent_text = soup.find(lambda x: 'Recent reviews' in x)

# %%
recent_text.get_text(strip=True)
# Out:
# 'Recent reviews'

# %%
flutter_url = 'https://www.trustpilot.com/review/flutterwave.com'
response_flutter = requests.get(flutter_url)
soup_flutter = BeautifulSoup(response_flutter.content, 'lxml')

# %%
soup_flutter
# Out:
# <!DOCTYPE html>
# <html lang="en-US"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="https://cdn.trustpilot.net/brand-assets/4.3.0/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="/manifest.json" rel="manifest"/><meta content="Trustpilot" name="application-name"/><meta content="#1c1c1c" name="theme-color"/><link href="https://cdn.trustpilot.net/brand-assets/4.3.0/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><link href="https://cdn.trustpilot.net/brand-assets/4.3.0/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="https://cdn.trustpilot.net/brand-assets/4.3.0/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link color="#00b67a" href="https://cdn.trustpilot.net/brand-assets/4.3.0/favicons/safari-pinned-tab.svg" rel="mask-icon"/><meta content="Trustpilot" name="apple-mobile-web-app-title"/><meta content="#1c1c1c" name="msapplication-TileColor"/><script>
#         /* 'Disable' Segments Querystring API */
#         (function() {
#           var os = location.search;
#           var ns = os.length ? '?'+os.substring(1).split('&').filter(function(param){return !/^ajs_(aid|event|uid)=/i.test(param);}).join('&') : '';
#           if (typeof window.history === 'object' && os !== ns) {
#             window.history.replaceState({}, '', location.pathname + ns)
#           }
#         })();
#         /* Segment snippet */
#         !function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug","page","once","off","on","addSourceMiddleware","addIntegrationMiddleware","setAnonymousId","addDestinationMiddleware"];analytics.factory=function(e){return function(){var t=Array.prototype.slice.call(arguments);t.unshift(e);analytics.push(t);return analytics}};for(var e=0;e<analytics.methods.length;e++){var key=analytics.methods[e];analytics[key]=analytics.factory(key)}analytics.load=function(key,e){var t=document.createElement("script");t.type="text/javascript";t.async=!0;t.src="https://cdn.segment.com/analytics.js/v1/" + key + "/analytics.min.js";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n);analytics._loadOptions=e};
#         analytics._writeKey="8tb69qtawc";
#         analytics.SNIPPET_VERSION="4.15.2";
#         }}();
#       </script><script>
#             (function(h){
#               h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#               h._hjSettings={hjid:391767,hjsv:6};
#             })(window);
#           </script><script class="optanon-category-C0002" src="https://static.hotjar.com/c/hotjar-391767.js?sv=6" type="text/plain"></script><link crossorigin="" href="https://businessunitprofile-cdn.trustpilot.net" rel="preconnect"/><link crossorigin="" href="https://cdn.trustpilot.net/" rel="preconnect"/><link crossorigin="" href="https://api.amplitude.com/" rel="preconnect"/><link crossorigin="" href="https://user-images.trustpilot.com/" rel="preconnect"/><link href="https://cdn.segment.com/analytics.js/v1/8tb69qtawc/analytics.min.js" rel="prefetch"/><link href="https://static.hotjar.com/c/hotjar-391767.js?sv=6" rel="prefetch"/><link crossorigin="" href="https://cdn.cookielaw.org" rel="preconnect"/><link crossorigin="" href="https://geolocation.onetrust.com" rel="preconnect"/><script data-domain-script="84cb5c09-05e4-488b-b71c-2fe171dca5e5" data-language="en-US" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="application/javascript"></script><script>
#           function OptanonWrapper() {
#             var event = new CustomEvent("OptanonWrapper");
#             document.dispatchEvent(event);
#           }</script><script nomodule="">
#         if (window.location.pathname !== '/error/upgradebrowser') {
#           window.location = '/error/upgradebrowser?status=browser';
#         }
#       </script><script class="optanon-category-C0002" id="nr-script" type="text/plain">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.eu01.nr-data.net","errorBeacon":"bam.eu01.nr-data.net","licenseKey":"NRBR-ab2d2379f7d606ec0e0","applicationID":"462890258","agentToken":null,"applicationTime":191.707608,"transactionName":"MhBSZQoZXkZXAUQNDgtaZ1QaPkJUWwdHCxMOIEJYVzZVTUIIQ0smICEfHgodRlxTFR8/AxAGWV8dC0NgWAtEOQ==","queueTime":0,"ttGuid":"c12b137dc794d341"}; (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.eu01.nr-data.net"]},feature_flags:["soft_nav"],distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"538682499",accountID:"4385887",trustKey:"4385887",xpid:"UAUPVF5bDxAEUlNaDgEFU1w=",licenseKey:"NRBR-ab2d2379f7d606ec0e0",applicationID:"462890258",browserID:"538682499"};;/*! For license information please see nr-loader-spa-1.307.0.min.js.LICENSE.txt */
# (()=>{var e,t,r={384:(e,t,r)=>{"use strict";r.d(t,{NT:()=>a,US:()=>u,Zm:()=>o,bQ:()=>d,dV:()=>c,pV:()=>l});var n=r(6154),i=r(1863),s=r(1910);const a={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net"};function o(){return n.gm.NREUM||(n.gm.NREUM={}),void 0===n.gm.newrelic&&(n.gm.newrelic=n.gm.NREUM),n.gm.NREUM}function c(){let e=o();return e.o||(e.o={ST:n.gm.setTimeout,SI:n.gm.setImmediate||n.gm.setInterval,CT:n.gm.clearTimeout,XHR:n.gm.XMLHttpRequest,REQ:n.gm.Request,EV:n.gm.Event,PR:n.gm.Promise,MO:n.gm.MutationObserver,FETCH:n.gm.fetch,WS:n.gm.WebSocket},(0,s.i)(...Object.values(e.o))),e}function d(e,t){let r=o();r.initializedAgents??={},t.initializedAt={ms:(0,i.t)(),date:new Date},r.initializedAgents[e]=t}function u(e,t){o()[e]=t}function l(){return function(){let e=o();const t=e.info||{};e.info={beacon:a.beacon,errorBeacon:a.errorBeacon,...t}}(),function(){let e=o();const t=e.init||{};e.init={...t}}(),c(),function(){let e=o();const t=e.loader_config||{};e.loader_config={...t}}(),o()}},782:(e,t,r)=>{"use strict";r.d(t,{T:()=>n});const n=r(860).K7.pageViewTiming},860:(e,t,r)=>{"use strict";r.d(t,{$J:()=>u,K7:()=>c,P3:()=>d,XX:()=>i,Yy:()=>o,df:()=>s,qY:()=>n,v4:()=>a});const n="events",i="jserrors",s="browser/blobs",a="rum",o="browser/logs",c={ajax:"ajax",genericEvents:"generic_events",jserrors:i,logging:"logging",metrics:"metrics",pageAction:"page_action",pageViewEvent:"page_view_event",pageViewTiming:"page_view_timing",sessionReplay:"session_replay",sessionTrace:"session_trace",softNav:"soft_navigations",spa:"spa"},d={[c.pageViewEvent]:1,[c.pageViewTiming]:2,[c.metrics]:3,[c.jserrors]:4,[c.spa]:5,[c.ajax]:6,[c.sessionTrace]:7,[c.softNav]:8,[c.sessionReplay]:9,[c.logging]:10,[c.genericEvents]:11},u={[c.pageViewEvent]:a,[c.pageViewTiming]:n,[c.ajax]:n,[c.spa]:n,[c.softNav]:n,[c.metrics]:i,[c.jserrors]:i,[c.sessionTrace]:s,[c.sessionReplay]:s,[c.logging]:o,[c.genericEvents]:"ins"}},944:(e,t,r)=>{"use strict";r.d(t,{R:()=>i});var n=r(3241);function i(e,t){"function"==typeof console.debug&&(console.debug("New Relic Warning: https://github.com/newrelic/newrelic-browser-agent/blob/main/docs/warning-codes.md#".concat(e),t),(0,n.W)({agentIdentifier:null,drained:null,type:"data",name:"warn",feature:"warn",data:{code:e,secondary:t}}))}},993:(e,t,r)=>{"use strict";r.d(t,{A$:()=>s,ET:()=>a,TZ:()=>o,p_:()=>i});var n=r(860);const i={ERROR:"ERROR",WARN:"WARN",INFO:"INFO",DEBUG:"DEBUG",TRACE:"TRACE"},s={OFF:0,ERROR:1,WARN:2,INFO:3,DEBUG:4,TRACE:5},a="log",o=n.K7.logging},1687:(e,t,r)=>{"use strict";r.d(t,{Ak:()=>d,Ze:()=>h,x3:()=>u});var n=r(3241),i=r(7836),s=r(3606),a=r(860),o=r(2646);const c={};function d(e,t){const r={staged:!1,priority:a.P3[t]||0};l(e),c[e].get(t)||c[e].set(t,r)}function u(e,t){e&&c[e]&&(c[e].get(t)&&c[e].delete(t),p(e,t,!1),c[e].size&&f(e))}function l(e){if(!e)throw new Error("agentIdentifier required");c[e]||(c[e]=new Map)}function h(e="",t="feature",r=!1){if(l(e),!e||!c[e].get(t)||r)return p(e,t);c[e].get(t).staged=!0,f(e)}function f(e){const t=Array.from(c[e]);t.every(([e,t])=>t.staged)&&(t.sort((e,t)=>e[1].priority-t[1].priority),t.forEach(([t])=>{c[e].delete(t),p(e,t)}))}function p(e,t,r=!0){const a=e?i.ee.get(e):i.ee,c=s.i.handlers;if(!a.aborted&&a.backlog&&c){if((0,n.W)({agentIdentifier:e,type:"lifecycle",name:"drain",feature:t}),r){const e=a.backlog[t],r=c[t];if(r){for(let t=0;e&&t<e.length;++t)g(e[t],r);Object.entries(r).forEach(([e,t])=>{Object.values(t||{}).forEach(t=>{t[0]?.on&&t[0]?.context()instanceof o.y&&t[0].on(e,t[1])})})}}a.isolatedBacklog||delete c[t],a.backlog[t]=null,a.emit("drain-"+t,[])}}function g(e,t){var r=e[1];Object.values(t[r]||{}).forEach(t=>{var r=e[0];if(t[0]===r){var n=t[1],i=e[3],s=e[2];n.apply(i,s)}})}},1738:(e,t,r)=>{"use strict";r.d(t,{U:()=>f,Y:()=>h});var n=r(3241),i=r(9908),s=r(1863),a=r(944),o=r(5701),c=r(3969),d=r(8362),u=r(860),l=r(4261);function h(e,t,r,s){const h=s||r;!h||h[e]&&h[e]!==d.d.prototype[e]||(h[e]=function(){(0,i.p)(c.xV,["API/"+e+"/called"],void 0,u.K7.met ...
#
# The positive feedback extends to various aspects of the service, including payment processes and overall customer support. Reviewers highlight the proactive nature of the staff, who are always ready to assist and provide helpful solutions. Customers are particularly impressed with the team's ability to resolve issues quickly, making them feel confident and satisfied with the service provided.</span><button class="CDS_Typography_appearance-action__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Link_link__7f0c1c styles_readMore__sWM_1 styles_isTruncated__Gqlqv CDS_Link_asButton__7f0c1c CDS_Link_buttonInherit__7f0c1c CDS_Link_noUnderline__7f0c1c" data-testid="toggle-text-truncation-button" data-toggle-text-truncation-button="true" type="button">See more</button></p><div class="styles_hotjarContainer__dz_zf" id="hotjar-ai-summaries-inline-feedback"></div></div><div><div class="styles_heading__EoDER"><h3 class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-s__dd9b51">Based on these reviews</h3><span><span aria-label="Tooltip" data-state="closed" data-testid="tooltip-element" role="button" tabindex="0"><svg aria-hidden="true" class="CDS_Icon_icon__c30ce7" fill="inherit" height="16px" role="img" style="fill:#6C6C85" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M8 1a7 7 0 1 0 0 14A7 7 0 0 0 8 1ZM0 8a8 8 0 1 1 16 0A8 8 0 0 1 0 8Z" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M7.5 7h-.75V6H8.5v5.502h.75v1h-2.5v-1h.75V7ZM6.75 4a1 1 0 1 1 2 0 1 1 0 0 1-2 0Z" fill-rule="evenodd"></path></svg></span></span></div><div class="styles_carouselWrapper__2CWyY"><button aria-label="SCROLL FORWARD" class="CDS_Button_button__cb9d05 CDS_Button_s__cb9d05 CDS_Button_appearance-secondary__cb9d05 CDS_Button_circle__cb9d05 styles_scrollButtonRight__2DrYl" data-scroll-forward-button="true" data-testid="SCROLL FORWARD" name="scroll-forward" type="button"><span class="CDS_Typography_appearance-inherit__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xxxs__dd9b51 CDS_Typography_disableResponsiveSizing__dd9b51 CDS_Button_buttonText__cb9d05"><span class="CDS_Button_iconSpan__cb9d05"><svg aria-hidden="true" class="CDS_Icon_icon__c30ce7 CDS_Icon_inherit__c30ce7" fill="inherit" height="16px" role="img" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg"><path d="m12.806 7.987-.343.375-6.344 6.344-.719-.718 6-6-5.656-5.626-.344-.375.719-.687 6.687 6.687Z"></path></svg></span></span></button><div class="styles_reviewSummarySection__o6B2R styles_scrollbarHide__jV7cU"><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for OLISAELOKA DIKE OKEKE" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_imageWrapper__dd33e0" data-testid="consumer-avatar" style="width:44px;height:44px;min-width:44px;min-height:44px"><img alt="" data-consumer-avatar-image="true" data-nimg="1" decoding="async" height="44" loading="lazy" src="https://user-images.trustpilot.com/599210f80000ff000abbd584/73x73.png" style="color:transparent" width="44"/></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true" data-cpl="true" href="/users/599210f80000ff000abbd584" name="consumer-profile" rel="nofollow" target="_self"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 styles_consumerName__xKr9c" data-consumer-name-typography="true">OLISAELOKA DIKE OKEKE</span><div class="styles_consumerExtraDetails__NY6RP" data-consumer-reviews-count="2"><div class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51"><time class="" data-cpl="true" data-service-review-date-time-ago="true" datetime="2025-12-30T14:56:48.000Z">Dec 30, 2025</t ...
# Great company, great product, great customer service!... <span class="CDS_Typography_appearance-action__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_default__dd9b51 styles_seeMore__J_tOL">See more</span></p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for Kyomukama Vicent" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_imageWrapper__dd33e0" data-testid="consumer-avatar" style="width:44px;height:44px;min-width:44px;min-height:44px"><img alt="" data-consumer-avatar-image="true" data-nimg="1" decoding="async" height="44" loading="lazy" src="https://user-images.trustpilot.com/64dcab1b3610b700117c23cf/73x73.png" style="color:transparent" width="44"/></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true" data-cpl="true" href="/users/64dcab1b3610b700117c23cf" name="consumer-profile" rel="nofollow" target="_self"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 styles_consumerName__xKr9c" data-consumer-name-typography="true">Kyomukama Vicent</span><div class="styles_consumerExtraDetails__NY6RP" data-consumer-reviews-count="2"><div class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51"><time class="" data-cpl="true" data-service-review-date-time-ago="true" datetime="2026-01-02T16:28:23.000Z">Jan 2, 2026</time></div></div></a></div></aside><div class="styles_starRating__BhKtt"><img alt="Rated 5 out of 5 stars" class="CDS_StarRating_starRating__614d2e" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-5.svg" width="84px"/></div><div class="styles_reviewText__q8Zhv" role="button" tabindex="0"><p class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-l__dd9b51" data-relevant-review-text-typography="true">I was helped from the moment I raised an issue until it was resolved. The customer support team is awesome 👌 </p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for Diamond Connect" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_imageWrapper__dd33e0" data-testid="consumer-avatar" style="width:44px;height:44px;min-width:44px;min-height:44px"><img alt="" data-consumer-avatar-image="true" data-nimg="1" decoding="async" height="44" loading="lazy" src="https://user-images.trustpilot.com/692a386200ecba10376f5d75/73x73.png" style="color:transparent" width="44"/></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true" data-cpl="true" href="/users/692a386200ecba10376f5d75" name="consumer-profile" rel="nofollow" target="_self"><span cla ...
# The verification process was not also difficult because you can always continue from where you stopped if the page closes</p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for Jacob Bioko" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_imageWrapper__dd33e0" data-testid="consumer-avatar" style="width:44px;height:44px;min-width:44px;min-height:44px"><img alt="" data-consumer-avatar-image="true" data-nimg="1" decoding="async" height="44" loading="lazy" src="https://user-images.trustpilot.com/6933e5d500ecba06ba7ae9c5/73x73.png" style="color:transparent" width="44"/></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true" data-cpl="true" href="/users/6933e5d500ecba06ba7ae9c5" name="consumer-profile" rel="nofollow" target="_self"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 styles_consumerName__xKr9c" data-consumer-name-typography="true">Jacob Bioko</span><div class="styles_consumerExtraDetails__NY6RP" data-consumer-reviews-count="1"><div class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51"><time class="" data-cpl="true" data-service-review-date-time-ago="true" datetime="2025-12-06T10:14:24.000Z">Dec 6, 2025</time></div></div></a></div></aside><div class="styles_starRating__BhKtt"><img alt="Rated 5 out of 5 stars" class="CDS_StarRating_starRating__614d2e" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-5.svg" width="84px"/></div><div class="styles_reviewText__q8Zhv" role="button" tabindex="0"><p class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-l__dd9b51" data-relevant-review-text-typography="true">The prompt response, professionalism and kind response of the customer support from flutterwave is top notch. I will be honest I have never enjoyed a customer support any where, not even in physical b... <span class="CDS_Typography_appearance-action__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_default__dd9b51 styles_seeMore__J_tOL">See more</span></p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for Epimack Chami" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_imageWrapper__dd33e0" data-testid="consumer-avatar" style="width:44px;height:44px;min-width:44px;min-height:44px"><img alt="" data-consumer-avatar-image="true" data-nimg="1" decoding="async" height="44" loading="lazy" src="https://user-images.trustpilot.com/68dfb2c47e136964935b5a0b/73x73.png" style="color:transparent" width="44"/></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data- ...
#
# One improvement that would make it even better is to ens... <span class="CDS_Typography_appearance-action__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_default__dd9b51 styles_seeMore__J_tOL">See more</span></p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for Eze Rita Chinonso" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_imageWrapper__dd33e0" data-testid="consumer-avatar" style="width:44px;height:44px;min-width:44px;min-height:44px"><img alt="" data-consumer-avatar-image="true" data-nimg="1" decoding="async" height="44" loading="lazy" src="https://user-images.trustpilot.com/68a372bb65125ed2c04cbb8c/73x73.png" style="color:transparent" width="44"/></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true" data-cpl="true" href="/users/68a372bb65125ed2c04cbb8c" name="consumer-profile" rel="nofollow" target="_self"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 styles_consumerName__xKr9c" data-consumer-name-typography="true">Eze Rita Chinonso</span><div class="styles_consumerExtraDetails__NY6RP" data-consumer-reviews-count="1"><div class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51"><time class="" data-cpl="true" data-service-review-date-time-ago="true" datetime="2025-08-18T20:37:39.000Z">Aug 18, 2025</time></div></div></a></div></aside><div class="styles_starRating__BhKtt"><img alt="Rated 5 out of 5 stars" class="CDS_StarRating_starRating__614d2e" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-5.svg" width="84px"/></div><div class="styles_reviewText__q8Zhv" role="button" tabindex="0"><p class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-l__dd9b51" data-relevant-review-text-typography="true">Am fully satisfied with flutterwave team for their smoothness and fastness in replying your customers. I was amazed with how they replied my mail in seconds and was always ready to help out.
# My fir... <span class="CDS_Typography_appearance-action__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_default__dd9b51 styles_seeMore__J_tOL">See more</span></p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for Ngoh Harison" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_imageWrapper__dd33e0" data-testid="consumer-avatar" style="width:44px;height:44px;min-width:44px;min-height:44px"><img alt="" data-consumer-avatar-image="true" data-nimg="1" decoding="async" height="44" loading="lazy" src="https://user-images.trustpilot.com/689b6fd465125e5d25444813/73x73.png" style="color:transparent" width="44"/></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true" data-cpl="true" href="/users/689b6fd465125e5d25444813" name="consumer-profile" rel="nofollow" target="_self"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 styles_consumerName__xKr9c" data-consumer-name-typography="true">Ngoh Harison</span><div class="styles_consumerExtraDetails__NY6RP" data-consumer-reviews-count="1"><div class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51"><time class="" data-cpl="true" data-service-review-date-time-ago="true" datetime="2025-08-12T18:47:17.000Z">Aug 12, 2025</time></div></div></a></div></aside><div class="styles_starRating__BhKtt"><img alt="Rated 5 out of 5 stars" class="CDS_StarRating_starRating__614d2e" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-5.svg" width="84px"/></div><div class="styles_reviewText__q8Zhv" role="button" tabindex="0"><p class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-l__dd9b51" data-relevant-review-text-typography="true">Honestly, I will say Fluterwave customer care is top notch. When you write they respond, when you call they answer just at the right time. I like the clarity and professionalism in communication. This... <span class="CDS_Typography_appearance-action__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_default__dd9b51 styles_seeMore__J_tOL">See more</span></p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for AfriMarket Online Hub" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_imageWrapper__dd33e0" data-testid="consumer-avatar" style="width:44px;height:44px;min-width:44px;min-height:44px"><img alt="" data-consumer-avatar-image="true" data-nimg="1" decoding="async" height="44" loading="lazy" src="https://user-images.trustpilot.com/68cdee647b741c4dc29bfcb0/73x73.png" style="color:transparent" width="44"/></div><a class="link_internal__Eam_ ...
# Flutterwave is blessed with very good and experienced staff.
# They say, the first impression last longer. My first transaction with the company was a good as being... <span class="CDS_Typography_appearance-action__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_default__dd9b51 styles_seeMore__J_tOL">See more</span></p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for Kimanga" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_avatar__dd33e0 CDS_Avatar_green__dd33e0" data-testid="consumer-avatar" style="width:44px;min-width:44px;height:44px;min-height:44px"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 CDS_Typography_disableResponsiveSizing__dd9b51 CDS_Avatar_avatarName__dd33e0">KI</span></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true" data-cpl="true" href="/users/690a26cc4064147ead30ecb0" name="consumer-profile" rel="nofollow" target="_self"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 styles_consumerName__xKr9c" data-consumer-name-typography="true">Kimanga</span><div class="styles_consumerExtraDetails__NY6RP" data-consumer-reviews-count="1"><div class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51"><time class="" data-cpl="true" data-service-review-date-time-ago="true" datetime="2025-11-04T18:16:38.000Z">Nov 4, 2025</time></div></div></a></div></aside><div class="styles_starRating__BhKtt"><img alt="Rated 4 out of 5 stars" class="CDS_StarRating_starRating__614d2e" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-4.svg" width="84px"/></div><div class="styles_reviewText__q8Zhv" role="button" tabindex="0"><p class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-l__dd9b51" data-relevant-review-text-typography="true">The quick response and the engagement of the team in wanting to support a new client-me to onboard. The efficiency and clarity expressed is by far exceptional. Thank you keep it up</p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for Eunice Olaoluwa Ayoola" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_imageWrapper__dd33e0" data-testid="consumer-avatar" style="width:44px;height:44px;min-width:44px;min-height:44px"><img alt="" data-consumer-avatar-image="true" data-nimg="1" decoding="async" height="44" loading="lazy" src="https://user-images.trustpilot.com/690bf41851678e997a867018/73x73.png" style="color:transparent" width="44"/></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true ...
#
# In a world where a... <span class="CDS_Typography_appearance-action__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_default__dd9b51 styles_seeMore__J_tOL">See more</span></p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for Oluwole" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_avatar__dd33e0 CDS_Avatar_green__dd33e0" data-testid="consumer-avatar" style="width:44px;min-width:44px;height:44px;min-height:44px"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 CDS_Typography_disableResponsiveSizing__dd9b51 CDS_Avatar_avatarName__dd33e0">OL</span></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true" data-cpl="true" href="/users/69283368ef3d6c1965d9318d" name="consumer-profile" rel="nofollow" target="_self"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 styles_consumerName__xKr9c" data-consumer-name-typography="true">Oluwole</span><div class="styles_consumerExtraDetails__NY6RP" data-consumer-reviews-count="1"><div class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51"><time class="" data-cpl="true" data-service-review-date-time-ago="true" datetime="2025-11-27T13:18:50.000Z">Nov 27, 2025</time></div></div></a></div></aside><div class="styles_starRating__BhKtt"><img alt="Rated 5 out of 5 stars" class="CDS_StarRating_starRating__614d2e" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-5.svg" width="84px"/></div><div class="styles_reviewText__q8Zhv" role="button" tabindex="0"><p class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-l__dd9b51" data-relevant-review-text-typography="true">I have never experienced a wonderful service like the flutterwave before. Since I reached out to them, they have been on top of the issue 24/7.</p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for Auwal Muhammad" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_imageWrapper__dd33e0" data-testid="consumer-avatar" style="width:44px;height:44px;min-width:44px;min-height:44px"><img alt="" data-consumer-avatar-image="true" data-nimg="1" decoding="async" height="44" loading="lazy" src="https://user-images.trustpilot.com/68e4af8b3603fed5826683c5/73x73.png" style="color:transparent" width="44"/></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true" data-cpl="true" href="/users/68e4af8b3603fed5826683c5" name="consumer-profile" rel="nofollow" target="_self"><span class="CDS ...
# Quick responses
# And they ensure your issue is resolved
# Very helpful overall 💯💯</p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for Perfection Imonikhe" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_avatar__dd33e0 CDS_Avatar_green__dd33e0" data-testid="consumer-avatar" style="width:44px;min-width:44px;height:44px;min-height:44px"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 CDS_Typography_disableResponsiveSizing__dd9b51 CDS_Avatar_avatarName__dd33e0">PI</span></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true" data-cpl="true" href="/users/693460b06148ea43b2fbed8c" name="consumer-profile" rel="nofollow" target="_self"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 styles_consumerName__xKr9c" data-consumer-name-typography="true">Perfection Imonikhe</span><div class="styles_consumerExtraDetails__NY6RP" data-consumer-reviews-count="1"><div class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51"><time class="" data-cpl="true" data-service-review-date-time-ago="true" datetime="2025-12-06T18:58:35.000Z">Dec 6, 2025</time></div></div></a></div></aside><div class="styles_starRating__BhKtt"><img alt="Rated 4 out of 5 stars" class="CDS_StarRating_starRating__614d2e" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-4.svg" width="84px"/></div><div class="styles_reviewText__q8Zhv" role="button" tabindex="0"><p class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-l__dd9b51" data-relevant-review-text-typography="true">Great experience but I will like them to work on the settlement cause it takes to much days </p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for abdur-rahman odusote" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><div class="CDS_Avatar_imageWrapper__dd33e0" data-testid="consumer-avatar" style="width:44px;height:44px;min-width:44px;min-height:44px"><img alt="" data-consumer-avatar-image="true" data-nimg="1" decoding="async" height="44" loading="lazy" src="https://user-images.trustpilot.com/69416c9a31cbb9b9ab6fdeed/73x73.png" style="color:transparent" width="44"/></div><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true" data-cpl="true" href="/users/69416c9a31cbb9b9ab6fdeed" name="consumer-profile" rel="nofollow" target="_self"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 styles_consumerName__xKr9c" data-consumer-name-typography="true">abdur- ...
# I had an issue with receiving receipt for a payment made, and within minutes of reaching out, it was resolved. The mistake was from me,... <span class="CDS_Typography_appearance-action__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_default__dd9b51 styles_seeMore__J_tOL">See more</span></p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article><article class="styles_carouselReviewCard__YIr6O styles_reviewCard__meSdm" data-service-review-card-paper="true"><aside aria-label="Info for Umar Yusuf" class="styles_consumerInfoWrapper__6HN5O"><div class="styles_consumerDetailsWrapper__4eZod"><button aria-controls="radix-:R9d5pahnnv6:" aria-expanded="false" aria-haspopup="dialog" aria-label="Umar Yusuf" class="styles_btnWrapper__arGPQ" data-state="closed" type="button"><div class="CDS_Avatar_imageWrapper__dd33e0" data-testid="consumer-avatar" style="width:44px;height:44px;min-width:44px;min-height:44px"><img alt="" data-consumer-avatar-image="true" data-nimg="1" decoding="async" height="44" loading="lazy" src="https://user-images.trustpilot.com/67c47153cfa97a42da5a5232/73x73.png" style="color:transparent" width="44"/></div><span class="styles_badge__oQ9m4"><svg aria-hidden="true" class="CDS_Icon_icon__c30ce7 CDS_Icon_default__c30ce7" fill="inherit" height="14px" role="img" viewbox="0 0 16 16" width="14px" xmlns="http://www.w3.org/2000/svg"><path class="ic-verified-user" d="M1 3a2 2 0 0 1 2-2h10a2 2 0 0 1 2 2v7.989a2 2 0 0 1-1.298 1.873l-5 1.875c-.453.17-.951.17-1.404 0l-5-1.875A2 2 0 0 1 1 10.989V3Z"></path><path class="ic-verified-user-check" d="M11.618 6.12a.875.875 0 1 0-1.236-1.24L7.03 8.22 5.66 6.647a.875.875 0 0 0-1.32 1.15l1.768 2.03c.041.047.086.089.135.125a.875.875 0 0 0 1.364.163l4.01-3.995Z"></path></svg></span></button><a class="link_internal__Eam_b link_wrapper__ahpyq styles_consumerDetails__POC79" data-consumer-profile-link="true" data-cpl="true" href="/users/67c47153cfa97a42da5a5232" name="consumer-profile" rel="nofollow" target="_self"><span class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 styles_consumerName__xKr9c" data-consumer-name-typography="true">Umar Yusuf</span><div class="styles_consumerExtraDetails__NY6RP" data-consumer-reviews-count="4"><div class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51"><time class="" data-cpl="true" data-service-review-date-time-ago="true" datetime="2025-03-02T16:55:37.000Z">Mar 2, 2025</time></div></div></a></div></aside><div class="styles_starRating__BhKtt"><img alt="Rated 5 out of 5 stars" class="CDS_StarRating_starRating__614d2e" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-5.svg" width="84px"/></div><div class="styles_reviewText__q8Zhv" role="button" tabindex="0"><p class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-l__dd9b51" data-relevant-review-text-typography="true">Throughout my Online Content Creation (Do it yourself) activities, i have not seen so easily to built through instruction and template from A-Z approach like this one provide by Flutterwave.
#
# I am e... <span class="CDS_Typography_appearance-action__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_default__dd9b51 styles_seeMore__J_tOL">See more</span></p><div class="styles_companyReply__WrkCW"><svg fill="none" height="13" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M1 1V1C1 7.07513 5.92574 12 12.0009 12C12.3442 12 12.6783 12 13 12" stroke="#E5E5DD" stroke-linecap="round" stroke-width="2"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Company replied</p></div></div><div class="styles_reviewActionsVariant__FKFd6"></div></article></div><div class="styles_gradientOverlay__tyZbh" data-at-end="false" data-at-start="true"></div></div></div><div class="styles_buttonContainer__sWHVs"><button class="CDS_Button_button__cb9d05 CDS_Button_l__cb9d05 CDS_Button_appearance-secondary__cb9d05 CDS_Button_iconRight__cb9d05 styles_seeAllReviewsButton__ffbcE" data-see-all-reviews-button="true" name="See all reviews" type="button"><span class="CDS_Typography_appearance-inherit__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-xs__dd9b51 CDS_Typography_disableResponsiveSizing__dd9b51 CDS_Button_buttonText__cb9d05">See all <!-- -->928<!-- --> reviews<span class="CDS_Button_iconSpan__cb9d05"><svg aria-hidden="true" class="CDS_Icon_icon__c30ce7 CDS_Icon_inherit__c30ce7" fill="inherit" height="16px" role="img" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg"><g><path d="m8.396 4.957 2.646 2.646H3.25v1h7.793L8.396 11.25l.708.707 3.853-3.853L9.104 4.25l-.708.707Z"></path><path clip-rule="evenodd" d="M8 16A8 8 0 1 0 8 0a8 8 0 0 0 0 16Zm7-8A7 7 0 1 1 1 8a7 7 0 0 1 14 0Z" fill-rule="evenodd"></path></g></svg></span></span></button><span class="styles_popoverTrigger__3_x4d"><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51 styles_popoverText__u92X7">We perform checks on reviews</p><button aria-controls="radix-:R1aahnnv6:" aria-expanded="false" aria-haspopup="dialog" aria-label="Information about trustworthy reviews" class="styles_iconButton__uOCbk" data-state="closed" type="button"><svg aria-hidden="true" class="CDS_Icon_icon__c30ce7 CDS_Icon_inherit__c30ce7 styles_popoverIcon__PKD90" fill="inherit" height="16px" role="img" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M8 1a7 7 0 1 0 0 14A7 7 0 0 0 8 1ZM0 8a8 8 0 1 1 16 0A8 8 0 0 1 0 8Z" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M7.5 7h-.75V6H8.5v5.502h.75v1h-2.5v-1h.75V7ZM6.75 4a1 1 0 1 1 2 0 1 1 0 0 1-2 0Z" fill-rule="evenodd"></path></svg></button></span></div><hr class="CDS_Divider_divider__7f1ed9 CDS_Divider_subtle__7f1ed9"/></div><div class="styles_companyDetails__30xkf" data-business-unit-about-section="true"><h2 class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_heading-m__dd9b51">Company details</h2><div class="styles_detailsWrapper__3QFeh"><div class="styles_tooltipContainer__dM6Jp"><span><button class="styles_basicActivityButton__SIhLv" data-state="closed"><svg aria-hidden="true" class="CDS_Icon_icon__c30ce7 CDS_Icon_positive__c30ce7" fill="inherit" height="16px" role="img" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M12.723 5.69 7.12 11.56 4.008 8.45l.707-.707 2.388 2.388L12 5l.723.69Z" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M3.05 3.05a7 7 0 1 0 9.9 9.9 7 7 0 0 0-9.9-9.9Zm-.707 10.607A8 8 0 1 1 13.657 2.343 8 8 0 0 1 2.343 13.657Z" fill-rule="evenodd"></path></svg><p class="CDS_Typography_appearance-subtle__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-m__dd9b51">Active Trustpilot subscription</p></button></span></div><ol class="styles_flexRow__eqdt3"><li class="CDS_Typography_appearance-default__dd9b51 CDS_Typography_prettyStyle__dd9b51 CDS_Typography_body-s__dd9b51 styles ...

# %%
divs = soup_flutter.select('[data-testid="service-review-card-v2"]')

# %%
root = soup_flutter.select_one('div[data-testid="service-review-card-v2"]')

# %%
data = {}

name_el = root.select_one('[data-consumer-name-typography="true"]')
name = name_el.get_text(strip=True) if name_el else None
data['name'] = name

# %%
data
# Out:
# {'name': 'Regis H. NKUNDIMANA'}

# %%
import re

# %%
reviews_count_el = root.select_one('[data-consumer-reviews-count-typography="true"]')
m = re.search(r'(\d+)', reviews_count_el.get_text(strip=True)) if reviews_count_el else None
reviews_count = int(m.group(1)) if m else None
data['reviews_count'] = reviews_count

# %%
data
# Out:
# {'name': 'Regis H. NKUNDIMANA', 'reviews_count': 1}

# %%
text_el = root.select_one('[data-service-review-text-typography="true"]')
review_text = text_el.get_text(strip=True) if text_el else None
data['review_text'] = review_text

# %%
data
# Out:
# {'name': 'Regis H. NKUNDIMANA',
#  'reviews_count': 1,
#  'review_text': '⭐⭐⭐⭐⭐Excellent support and a smooth onboarding experience. The Flutterwave team was responsive, professional, and very helpful throughout the verification process. Clear guidance and timely assistance made everything easy. Highly recommended!'}

# %%
star_given = root.select_one('[data-service-review-rating]')
star_rating = None
if star_given and star_given.has_attr('data-service-review-rating'):
    rating_attr = star_given['data-service-review-rating']
    m = re.search(r'(\d+)', rating_attr) if rating_attr else None
    if m:
        star_rating = int(m.group(1))

data['star_rating'] = star_rating

# %%
data
# Out:
# {'name': 'Regis H. NKUNDIMANA',
#  'reviews_count': 1,
#  'review_text': '⭐⭐⭐⭐⭐Excellent support and a smooth onboarding experience. The Flutterwave team was responsive, professional, and very helpful throughout the verification process. Clear guidance and timely assistance made everything easy. Highly recommended!',
#  'star_given': None,
#  'star_rating': 5}

# %%
date = root.select_one('[data-service-review-date-time-ago]')
if date:
    date_text = date.get_text(strip=True)
    data['date'] = date_text

# %%
data
# Out:
# {'name': 'Regis H. NKUNDIMANA',
#  'reviews_count': 1,
#  'review_text': '⭐⭐⭐⭐⭐Excellent support and a smooth onboarding experience. The Flutterwave team was responsive, professional, and very helpful throughout the verification process. Clear guidance and timely assistance made everything easy. Highly recommended!',
#  'star_given': None,
#  'star_rating': 5,
#  'date': '14 hours ago'}

# %%
# Delete star given to avoid confusion
del data['star_given']

# %%
data
# Out:
# {'name': 'Regis H. NKUNDIMANA',
#  'reviews_count': 1,
#  'review_text': '⭐⭐⭐⭐⭐Excellent support and a smooth onboarding experience. The Flutterwave team was responsive, professional, and very helpful throughout the verification process. Clear guidance and timely assistance made everything easy. Highly recommended!',
#  'star_rating': 5,
#  'date': '14 hours ago'}

# %%
pages = range(1, 6)
for page in pages: 
    flutter_url = f'https://www.trustpilot.com/review/flutterwave.com?page={page}'
    print(f'Processing URL: {flutter_url}')
# Out:
# Processing URL: https://www.trustpilot.com/review/flutterwave.com?page=1
# Processing URL: https://www.trustpilot.com/review/flutterwave.com?page=2
# Processing URL: https://www.trustpilot.com/review/flutterwave.com?page=3
# Processing URL: https://www.trustpilot.com/review/flutterwave.com?page=4
# Processing URL: https://www.trustpilot.com/review/flutterwave.com?page=5

# %%
pages = range(1, 6)
results = []

for page in pages: 
    flutter_url = f'https://www.trustpilot.com/review/flutterwave.com?page={page}'
    response_flutter = requests.get(flutter_url)
    soup_flutter = BeautifulSoup(response_flutter.content, 'lxml')

    review_cards = soup_flutter.select('[data-testid="service-review-card-v2"]')

    for root in review_cards:
        data = {}

        name_el = root.select_one('[data-consumer-name-typography="true"]')
        name = name_el.get_text(strip=True) if name_el else None
        data['name'] = name

        reviews_count_el = root.select_one('[data-consumer-reviews-count-typography="true"]')
        m = re.search(r'(\d+)', reviews_count_el.get_text(strip=True)) if reviews_count_el else None
        reviews_count = int(m.group(1)) if m else None
        data['reviews_count'] = reviews_count

        text_el = root.select_one('[data-service-review-text-typography="true"]')
        review_text = text_el.get_text(strip=True) if text_el else None
        data['review_text'] = review_text

        star_given = root.select_one('[data-service-review-rating]')
        star_rating = None
        if star_given and star_given.has_attr('data-service-review-rating'):
            rating_attr = star_given['data-service-review-rating']
            m = re.search(r'(\d+)', rating_attr) if rating_attr else None
            if m:
                star_rating = int(m.group(1))
        data['star_rating'] = star_rating

        date = root.select_one('[data-service-review-date-time-ago]')
        if date:
            date_text = date.get_text(strip=True)
            data['date'] = date_text

        results.append(data)

# %%
def fetch_reviews(url, pages):
    results = []

    for page in pages: 
        url = f'{url}?page={page}'
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'lxml')

        review_cards = soup.select('[data-testid="service-review-card-v2"]')

        for root in review_cards:
            data = {}

            name_el = root.select_one('[data-consumer-name-typography="true"]')
            name = name_el.get_text(strip=True) if name_el else None
            data['name'] = name

            reviews_count_el = root.select_one('[data-consumer-reviews-count-typography="true"]')
            m = re.search(r'(\d+)', reviews_count_el.get_text(strip=True)) if reviews_count_el else None
            reviews_count = int(m.group(1)) if m else None
            data['reviews_count'] = reviews_count

            text_el = root.select_one('[data-service-review-text-typography="true"]')
            review_text = text_el.get_text(strip=True) if text_el else None
            data['review_text'] = review_text

            star_given = root.select_one('[data-service-review-rating]')
            star_rating = None
            if star_given and star_given.has_attr('data-service-review-rating'):
                rating_attr = star_given['data-service-review-rating']
                m = re.search(r'(\d+)', rating_attr) if rating_attr else None
                if m:
                    star_rating = int(m.group(1))
            data['star_rating'] = star_rating

            date = root.select_one('[data-service-review-date-time-ago]')
            if date:
                date_text = date.get_text(strip=True)
                data['date'] = date_text

            results.append(data)
    return results

# %%
jumia_url = 'https://www.trustpilot.com/review/jumia.com.ng'
pages = range(1, 6)
jumia_reviews = fetch_reviews(jumia_url, pages)
jumia_df = pd.DataFrame(jumia_reviews)

# %%
jumia_df
# Out:
#                   name  reviews_count  \
# 0       Isioma Ibemesi              5
# 1                 Lily              2
# 2          Fatima Anas              1
# 3             Williams              2
# 4        Victor Iwegbu              1
# 5            LOGICMIND              1
# 6            Peter Joy              1
# 7       Isioma Ibemesi              1
# 8        Ogazi Trivian              1
# 9                Faith              1
# 10        Jones Cosmos              3
# 11             Olusola              3
# 12               Kenny              1
# 13    Beautiful People              1
# 14           Ese Rhema              1
# 15           Paul Hill              1
# 16  FIDELIA ESHAREFASA              7
# 17       James Josking              1
# 18      Bisola Johnson              2
# 19         Clem Elijah              1
#
#                                           review_text  star_rating  \
# 0   Updated Review & ApologyFor review dropped on ...            5
# 1   I bought a phone off this website the last tim...            3
# 2   I have been shopping with Jumia for over 5 yea...            3
# 3   I ordered an item a different item entirely wa...            1
# 4   I have been using Jumia Nigeria for some time,...            3
# 5   I honestly don’t understand how a company as b...            1
# 6   I had a good experience shopping on Jumia. My ...            1
# 7   1-Star Review: “Terrible Customer Service and ...            1
# 8   1-Star Review: “Terrible Customer Service and ...            1
# 9        Giving different things from what is ordered            1
# 10  Jumia is gradually going down the scale. Fake ...            1
# 11  THE MOST USELESS, INCOMPETENT, IRRESPONSIBLE C...            1
# 12  3-4 days for delivery from lagos to Aba... It'...            1
# 13  Their customer service is the poorest I’ve eve...            1
# 14  I have order a ton of items from jumia even th...            5
# 15  They're so poor......late delivery... Lagos to...            1
# 16  Took almost 2 months to wait for a shoe and th...            1
# 17  It takes forever to deliver product I do not r...            1
# 18  Jumia is a very useless platform to shop. We n...            1
# 19  If there's a way to give zero star, I would gl...            1
#
#             date
# 0    3 hours ago
# 1   Dec 29, 2025
# 2   Dec 26, 2025
# 3   Dec 11, 2025
# 4   Nov 22, 2025
# 5   Nov 18, 2025
# 6   Nov 15, 2025
# 7    Nov 6, 2025
# 8    Nov 6, 2025
# 9   Oct 30, 2025
# 10  Aug 22, 2025
# 11  Jul 26, 2025
# 12  Jul 12, 2025
# 13  Jun 20, 2025
# 14   Jun 7, 2025
# 15   May 9, 2025
# 16  Apr 11, 2025
# 17  Mar 10, 2025
# 18  Feb 28, 2025
# 19  Feb 18, 2025

# %%
paystack_url = 'https://www.trustpilot.com/review/paystack.com'
pages = range(1, 6)
paystack_reviews = fetch_reviews(paystack_url, pages)
paystack_df = pd.DataFrame(paystack_reviews)

# %%
paystack_df
# Out:
#                   name  reviews_count  \
# 0             Blue Pay              1
# 1    Netmarks Research              1
# 2        Comfort Akyae              1
# 3           Patrick L.              3
# 4        Young Techiez              1
# 5    First Class Beatz              1
# 6             A. Isaac              1
# 7          Vinny Mbevi              1
# 8     Djehuti Ventures              2
# 9          Sheba Macby              4
# 10           BHA alive              2
# 11    Ebetech Ventures              1
# 12          Eric Owusu              1
# 13      Ayoola Adesola              1
# 14       Victor Karani              1
# 15       Caleb Oladejo              6
# 16          Eric Gitau              1
# 17  Merveil Diatsonama              1
# 18           Carol Ken              1
# 19      Sylvester Ngwu              1
#
#                                           review_text  star_rating  \
# 0   My payout haven't been paid for more than a we...            1
# 1   If you want depression try this company. It's ...            1
# 2   If you want the best for your business, don't ...            1
# 3   I’ve been using Paystack for my business, and ...            5
# 4   The platform has been pretty seamless for me a...            5
# 5   This is a trashy entity, stay away from them i...            1
# 6   I've been using Paystack for the past 5 years ...            1
# 7   I never knew I would be a victim of this payst...            1
# 8   African Fintech is a mess. I thought Paystack ...            1
# 9   Paystack’s behaviour has been extremely suspic...            1
# 10  Please!!! Boycott Paystack, they are professio...            1
# 11  This is very bad, you withhold my money for al...            1
# 12  I am not surprised to see a lot of negative re...            1
# 13  Paystack is giving their customers difficultie...            1
# 14  I think platform is somehow a fraud. I have no...            1
# 15  Highly disappointed in you.1. While I have rep...            1
# 16  I am completely disappointed by paystack,  the...            1
# 17  They are holding my money it’s been over 2 wee...            1
# 18  My payouts have been pending a week now accoun...            1
# 19                                               None            5
#
#                     date
# 0           Dec 28, 2025
# 1           Dec 15, 2025
# 2            Dec 3, 2025
# 3           Nov 26, 2025
# 4           Nov 19, 2025
# 5           Nov 15, 2025
# 6            Nov 9, 2025
# 7            Nov 8, 2025
# 8            Nov 5, 2025
# 9   Updated Nov 15, 2025
# 10   Updated Nov 5, 2025
# 11          Oct 21, 2025
# 12          Oct 21, 2025
# 13          Oct 14, 2025
# 14           Oct 2, 2025
# 15          Sep 29, 2025
# 16          Sep 16, 2025
# 17           Sep 9, 2025
# 18           Sep 6, 2025
# 19           Sep 3, 2025

# %%
results
# Out:
# [{'name': 'Regis H. NKUNDIMANA',
#   'reviews_count': 1,
#   'review_text': '⭐⭐⭐⭐⭐Excellent support and a smooth onboarding experience. The Flutterwave team was responsive, professional, and very helpful throughout the verification process. Clear guidance and timely assistance made everything easy. Highly recommended!',
#   'star_rating': 5,
#   'date': '15 hours ago'},
#  {'name': 'Adigun Bunmi',
#   'reviews_count': 1,
#   'review_text': 'I most confess, I was wow by Flutterwave customer service for quick response to my email, I bought electric token and no token was released, I sent mail, message to the supplier but to no avail. Immediate I contacted Flutterwave, they responded in a jiffy and the token was released after they contacted the supplier.',
#   'star_rating': 5,
#   'date': 'A day ago'},
#  {'name': 'Ajileye Olawale',
#   'reviews_count': 1,
#   'review_text': 'Superb customer service experience',
#   'star_rating': 5,
#   'date': '3 days ago'},
#  {'name': 'Bismark Antwi Social life',
#   'reviews_count': 1,
#   'review_text': 'I like their customer care.',
#   'star_rating': 5,
#   'date': '3 days ago'},
#  {'name': 'Xusilent',
#   'reviews_count': 2,
#   'review_text': 'Flutterwave has been good for my business so far no doubt keep up the great work just the only problem is the onboarding/verification process can be exhausting lol which is normal for proper kyc but overall looks good',
#   'star_rating': 5,
#   'date': '6 days ago'},
#  {'name': 'Kyomukama Vicent',
#   'reviews_count': 2,
#   'review_text': 'I was helped from the moment I raised an issue until it was resolved. The customer support team is awesome 👌',
#   'star_rating': 5,
#   'date': 'Jan 2, 2026'},
#  {'name': 'Tamrole Co. Nig Ltd',
#   'reviews_count': 1,
#   'review_text': "Flutterwave has an outstanding support team. They guided me through the problems, working tirelessly around the clock. It's clear they are highly motivated. Excellent company, excellent product, and excellent customer service.",
#   'star_rating': 5,
#   'date': 'Jan 2, 2026'},
#  {'name': 'Peter Asante Addo',
#   'reviews_count': 1,
#   'review_text': 'I am generally satisfied with customer relations, feedbacks and assistance.',
#   'star_rating': 5,
#   'date': 'Jan 2, 2026'},
#  {'name': 'OLISAELOKA DIKE OKEKE',
#   'reviews_count': 2,
#   'review_text': "I must confess that I was wowed by Flutterwave Customer service response and follow up. I've used some other payment gateways, but must confess that their customer service is exceptional. There manner of approach too is commendable. They are quite doing a very good job.",
#   'star_rating': 5,
#   'date': 'Dec 30, 2025'},
#  {'name': 'Abdul-Hafees Tijani',
#   'reviews_count': 1,
#   'review_text': 'A good experience all together even though it took close to 2 weeks to close out. I appreciate the communication all through the experience.',
#   'star_rating': 4,
#   'date': 'Dec 30, 2025'},
#  {'name': 'El Tigre Mbaike',
#   'reviews_count': 2,
#   'review_text': 'The best. Better than Paystack',
#   'star_rating': 5,
#   'date': 'Dec 25, 2025'},
#  {'name': 'Iman Isyaku',
#   'reviews_count': 1,
#   'review_text': None,
#   'star_rating': 4,
#   'date': 'Dec 22, 2025'},
#  {'name': 'Michael Rich',
#   'reviews_count': 1,
#   'review_text': 'Great support team, timely responses and high level of professionality in all conversations.',
#   'star_rating': 5,
#   'date': 'Dec 22, 2025'},
#  {'name': 'Ayo Olatunji',
#   'reviews_count': 1,
#   'review_text': "I am thrilled by the response time and the customer service is great. It's a 10/10 score from me.",
#   'star_rating': 5,
#   'date': 'Dec 18, 2025'},
#  {'name': 'abdur-rahman odusote',
#   'reviews_count': 1,
#   'review_text': "The customer service is top-notch, with constant messages and calls to ensure both client satisfaction and issue resolution simultaneously. I think that's the least i can describe their service",
#   'star_rating': 5,
#   'date': 'Dec 16, 2025'},
#  {'name': 'Odiachi Daniel',
#   'reviews_count': 2,
#   'review_text': 'Very slow Resolution of Cross Border Payment DelaysThe system is usually fast but with a 60 to 70% success rate for cross border transactions.The moment your transaction pends for more than two minutes, forget it, it might reach its final status the upper week and then their customer support will keep promising a 48hour resolution window.Not good for a B2C at all',
#   'star_rating': 2,
#   'date': 'Dec 15, 2025'},
#  {'name': 'Innocent Emmanuel',
#   'reviews_count': 1,
#   'review_text': 'I like their customer support team they are swift and prompt in responding. Mary who attended to me followed through until everything was resolved. Keep it up flutterwave continue to make life easier for businesses. Even now I can receive my payments seamlessly.',
#   'star_rating': 5,
#   'date': 'Dec 12, 2025'},
#  {'name': 'Cynthia Ojimadu',
#   'reviews_count': 6,
#   'review_text': 'I like their customer support team they are swift and prompt in responding. Mary who attended to me followed through until everything was resolved. Keep it up flutterwave continue to make life easier for businesses. Even now I can receive my payments seamlessly.',
#   'star_rating': 5,
#   'date': 'Dec 11, 2025'},
#  {'name': 'Nura Umar Inuwa',
#   'reviews_count': 6,
#   'review_text': 'Excellent service, good experience.Please keep it up 👍👍👍',
#   'star_rating': 5,
#   'date': 'Dec 10, 2025'},
#  {'name': 'Perfection Imonikhe',
#   'reviews_count': 1,
#   'review_text': 'Great experience but I will like them to work on the settlement cause it takes to much days',
#   'star_rating': 4,
#   'date': 'Dec 6, 2025'},
#  {'name': 'Jacob Bioko',
#   'reviews_count': 1,
#   'review_text': 'The prompt response, professionalism and kind response of the customer support from flutterwave is top notch. I will be honest I have never enjoyed a customer support any where, not even in physical banks, the way I enjoyed the support from flutterwave, they are fast in response and if there be any delays they do apologize and solve the problem. One thing I love about them is that they will always respond. And this is not the only time I have encountered the customer support and I will be glad to give them a 10/5, i am truly impressed and grateful for their services',
#   'star_rating': 5,
#   'date': 'Dec 6, 2025'},
#  {'name': 'Diamond Connect',
#   'reviews_count': 1,
#   'review_text': "If I'm to sum the support team in few words, it will be; dedicated, polite and understanding. They ensured there was a constant communication and feedback to get the issue solved. The communication and level of politeness made me know they were solving the problem and is in control of it. That made me trust them and was ensured they were in control and have the capacity to solve it. I've used companies in Nigeria but this is the best support team.",
#   'star_rating': 5,
#   'date': 'Nov 29, 2025'},
#  {'name': 'George Florence',
#   'reviews_count': 1,
#   'review_text': 'After a long review for about 3 weeks and  my account is now fully active and live for payment flexibility our audience , both old and new ones.  Customer service was great both call and email. I appreciate and thanks',
#   'star_rating': 4,
#   'date': 'Nov 28, 2025'},
#  {'name': 'Oluwole',
#   'reviews_count': 1,
#   'review_text': 'I have never experienced a wonderful service like the flutterwave before. Since I reached out to them, they have been on top of the issue 24/7.',
#   'star_rating': 5,
#   'date': 'Nov 27, 2025'},
#  {'name': 'Sunday Zuoke',
#   'reviews_count': 3,
#   'review_text': "Flutterwave has some of the best support staff. They walked me through the issues, working round the clock. I'm sure they are super motivated.Great company, great product, great customer service!Will definitely recommend.",
#   'star_rating': 5,
#   'date': 'Nov 26, 2025'},
#  {'name': 'Ekekpor Israel Etete',
#   'reviews_count': 1,
#   'review_text': 'The flutter waves team is excellent and swift to rectifying the difficulties I had with transfer.',
#   'star_rating': 5,
#   'date': 'Nov 25, 2025'},
#  {'name': 'Gerard',
#   'reviews_count': 1,
#   'review_text': 'I was informed via e-mail on a regular basis (daily) of my refund. Folakemi B was very helpful in resolving this matter. I just want to say a big thank you.',
#   'star_rating': 5,
#   'date': 'Nov 24, 2025'},
#  {'name': 'OLAJUMOKE JOHNSON',
#   'reviews_count': 2,
#   'review_text': 'Swift response and clear communication by the customer care team.',
#   'star_rating': 5,
#   'date': 'Nov 23, 2025'},
#  {'name': 'Agrokulture Nigeria Limited',
#   'reviews_count': 1,
#   'review_text': 'Response was swiftTheir customer service???The best 👌🏾',
#   'star_rating': 5,
#   'date': 'Nov 17, 2025'},
#  {'name': 'Maryam salahudeen',
#   'reviews_count': 1,
#   'review_text': 'Well, the customer support was swift . I got quick response when stuck.The verification process was not also difficult because you can always continue from where you stopped if the page closes',
#   'star_rating': 5,
#   'date': 'Nov 16, 2025'},
#  {'name': 'Kenechukwu Chukwukelue',
#   'reviews_count': 1,
#   'review_text': "Great customer service.My issues was attended to like I'm the only one on earth.",
#   'star_rating': 4,
#   'date': 'Nov 14, 2025'},
#  {'name': 'Amolytech Global Resources',
#   'reviews_count': 1,
#   'review_text': 'Flutterwave’s service is truly top-notch. Their responsiveness to customer challenges is nothing short of amazing, and every interaction leaves you feeling supported and valued. Navigating the platform is seamless, making payments, transactions, and account management effortless. I am thoroughly impressed and highly recommend Flutterwave to any business looking for a reliable and efficient payment solution.',
#   'star_rating': 5,
#   'date': 'Nov 14, 2025'},
#  {'name': 'Gregory',
#   'reviews_count': 1,
#   'review_text': 'Top notch servicesQuick responsesAnd they ensure your issue is resolvedVery helpful overall 💯💯',
#   'star_rating': 5,
#   'date': 'Nov 13, 2025'},
#  {'name': 'chiamaka oham',
#   'reviews_count': 2,
#   'review_text': 'The customer service assistant that assisted me was very helpful',
#   'star_rating': 5,
#   'date': 'Nov 12, 2025'},
#  {'name': 'Generalismo Egbawaibon',
#   'reviews_count': 3,
#   'review_text': 'Flutterwave is an awesome app for businesses and easy to integrate with an existing app, the commission is low and fair and transactions seamless',
#   'star_rating': 5,
#   'date': 'Nov 12, 2025'},
#  {'name': 'Israel Johnson',
#   'reviews_count': 1,
#   'review_text': 'Very comfortable to use',
#   'star_rating': 5,
#   'date': 'Nov 12, 2025'},
#  {'name': 'Godwin Peter',
#   'reviews_count': 1,
#   'review_text': 'They resolved it as soon as possible',
#   'star_rating': 5,
#   'date': 'Nov 10, 2025'},
#  {'name': 'Paul Simire',
#   'reviews_count': 1,
#   'review_text': "I'm new to the app and I had some issues with them but they were very professional enough to attend to my needs. But they just have to fix the issues of dollar rate. The conversion is lesser than the official rate.I highly recommend them.",
#   'star_rating': 5,
#   'date': 'Nov 10, 2025'},
#  {'name': 'Auwal Muhammad',
#   'reviews_count': 1,
#   'review_text': "I recently had an issue with my Flutterwave account and I must say, their customer support team is top-notch! They were very patient and understanding, and walked me through the process of resolving the issue.From the initial response to the final resolution, the team was prompt and professional. They provided clear instructions and followed up regularly to ensure that the issue was resolved.I was impressed by their willingness to listen and their commitment to finding a solution. The integration team was also very helpful and responsive, and they worked with my developer to resolve the issue.Overall, I'm satisfied with the experience and appreciate the efforts of the Flutterwave team. They're a great example of excellent customer service.",
#   'star_rating': 5,
#   'date': 'Nov 9, 2025'},
#  {'name': 'Allen Raymond',
#   'reviews_count': 1,
#   'review_text': 'Fast response',
#   'star_rating': 4,
#   'date': 'Nov 9, 2025'},
#  {'name': 'Nkemjika Maureen',
#   'reviews_count': 1,
#   'review_text': 'I was debited twice for an appointment booking without an appointment letter,all thanks 👍 to the great team of flutter wave to ensure I get back my fund. Much thanks to Solomon.',
#   'star_rating': 5,
#   'date': 'Nov 7, 2025'},
#  {'name': 'Prosperchidiebere Nwokoji',
#   'reviews_count': 1,
#   'review_text': 'Nice app but am having difficulty in linking my flutterwave account with my PayPal account',
#   'star_rating': 4,
#   'date': 'Nov 6, 2025'},
#  {'name': 'Candice Woodman',
#   'reviews_count': 1,
#   'review_text': 'Wow, awesome service from start to finish. Thank you Flutterwave for assisting me. All staff that assisted me was so friendly and helpful. Also thank you to Ifeanyi, amazing service!!!',
#   'star_rating': 5,
#   'date': 'Nov 6, 2025'},
#  {'name': 'Eunice Olaoluwa Ayoola',
#   'reviews_count': 1,
#   'review_text': 'What a good customer service! I was thinking it will take ages for them to reply because I sent a message at midnight but I was surprised. The response was fast and I liked it, I really liked it. I got support and the issue was resolved. Thanks Flutterwave',
#   'star_rating': 5,
#   'date': 'Nov 6, 2025'},
#  {'name': 'Kimanga',
#   'reviews_count': 1,
#   'review_text': 'The quick response and the engagement of the team in wanting to support a new client-me to onboard. The efficiency and clarity expressed is by far exceptional. Thank you keep it up',
#   'star_rating': 4,
#   'date': 'Nov 4, 2025'},
#  {'name': 'Tomilola',
#   'reviews_count': 1,
#   'review_text': 'My experience with Flutterwave was excellent. The support team showed great understanding and professionalism during my verification process. I’m very satisfied with their service',
#   'star_rating': 4,
#   'date': 'Nov 4, 2025'},
#  {'name': 'Utibe Sam',
#   'reviews_count': 1,
#   'review_text': "Best customer service, timely response to customer's complaints and follow up to know if customer's complaints has been resolved, it was just so good the experience I had with Flatterwave. Service delivery is top notch. ✅",
#   'star_rating': 5,
#   'date': 'Nov 4, 2025'},
#  {'name': 'Prince A',
#   'reviews_count': 2,
#   'review_text': 'I’m really impressed with Flutterwave’s service. Their support team — especially Ngozi — was professional and helpful throughout the process of activating international payments. My store is now live and successfully processing USD transactions smoothly. Great experience overall!Solvexa Smart Hub',
#   'star_rating': 5,
#   'date': 'Nov 3, 2025'},
#  {'name': 'G-CLASS GLOBAL RESOURCES',
#   'reviews_count': 4,
#   'review_text': 'It was very nice receiving payment through flutterwave.',
#   'star_rating': 5,
#   'date': 'Oct 30, 2025'},
#  {'name': 'Drill point',
#   'reviews_count': 1,
#   'review_text': 'Best cutomer service ive ever had trust me .. its all about patience',
#   'star_rating': 5,
#   'date': 'Oct 28, 2025'},
#  {'name': 'Uzoma Bailey Ayogu',
#   'reviews_count': 6,
#   'review_text': 'The CEO himself helped raise the issue to compliance and we got it resolved in record time. The fact he cared so deeply about us and our volume made it clear that this is the company I want to bank and grow with',
#   'star_rating': 5,
#   'date': 'Oct 27, 2025'},
#  {'name': 'Idowu Ajayi',
#   'reviews_count': 1,
#   'review_text': 'High response time.The customer service officers attended to me in a highly professional and respectful manner. Flutterwave is the best in terms of promptly resolving issues',
#   'star_rating': 5,
#   'date': 'Updated Nov 10, 2025'},
#  {'name': 'Samuel Mbugua',
#   'reviews_count': 1,
#   'review_text': 'just great customer services. and well articulated decision making. kudos flutterwave',
#   'star_rating': 5,
#   'date': 'Oct 27, 2025'},
#  {'name': 'kevin ronald',
#   'reviews_count': 1,
#   'review_text': 'Awesome.its way better than paystack',
#   'star_rating': 5,
#   'date': 'Oct 25, 2025'},
#  {'name': 'Tochukwu Okoh',
#   'reviews_count': 1,
#   'review_text': 'The responses l got and the professionalism were fantastic.',
#   'star_rating': 5,
#   'date': 'Oct 24, 2025'},
#  {'name': 'Abubakar Ibrahim Aruwa',
#   'reviews_count': 2,
#   'review_text': None,
#   'star_rating': 5,
#   'date': 'Oct 24, 2025'},
#  {'name': 'Pazy Monet',
#   'reviews_count': 2,
#   'review_text': 'My experiences with flutterwave had being nice so far , gotten an easy business payment integration all set without stress thanks to Flutterwave, Also their responses to emails and messages are very fast and issues solving is topnotch.... Kudos to the team',
#   'star_rating': 5,
#   'date': 'Oct 24, 2025'},
#  {'name': 'Vin',
#   'reviews_count': 1,
#   'review_text': "I'm still yet to believe what I experienced and called it to be going beyond limits to satisfy the masses with a flash approach and no stress. I got a mail from Flutterwave customer support; Folakemi as identified to me that I should send another account details of mine to be able to receive my refunds I was expecting few days ago since the primary account for the refund cannot process the payment. Folakemi kept me updated with a friendly-like message making me to worry less with no stress till I received the funds swiftly under 24hrs while I was expecting it should be two to three  market days. MUCH LOVE Folakemi",
#   'star_rating': 5,
#   'date': 'Oct 22, 2025'},
#  {'name': 'Lasisi Nafisat',
#   'reviews_count': 2,
#   'review_text': 'It was great using Flutterwave and it has been very helpful for me since have been using it.Thanks.',
#   'star_rating': 2,
#   'date': 'Oct 21, 2025'},
#  {'name': 'Bisiriyu Bilikis Agboola',
#   'reviews_count': 1,
#   'review_text': 'Their customers care relationship',
#   'star_rating': 5,
#   'date': 'Oct 20, 2025'},
#  {'name': 'Adjejevwe Tivere',
#   'reviews_count': 1,
#   'review_text': 'I will say am satisfied with the timely response and direct address to the problem',
#   'star_rating': 4,
#   'date': 'Oct 19, 2025'},
#  {'name': 'Dushi Apps',
#   'reviews_count': 1,
#   'review_text': "Very supportive team.  Available and open to support. So far I appreciate the sandbox, can't wait to go live.",
#   'star_rating': 5,
#   'date': 'Oct 18, 2025'},
#  {'name': 'Fideal',
#   'reviews_count': 2,
#   'review_text': 'Very good experience. Caring team.',
#   'star_rating': 5,
#   'date': 'Oct 16, 2025'},
#  {'name': 'Dami Jegz',
#   'reviews_count': 1,
#   'review_text': 'Honestly the support team are just do supportive 😂almost as fast as flash lightning speed reply 🙂 and reliable assistance to help resolve issues 😌👌',
#   'star_rating': 5,
#   'date': 'Oct 16, 2025'},
#  {'name': 'Abitegeka Ivan',
#   'reviews_count': 1,
#   'review_text': None,
#   'star_rating': 5,
#   'date': 'Oct 16, 2025'},
#  {'name': 'Jr Thomas Fred Lungu',
#   'reviews_count': 2,
#   'review_text': 'Flutterwave Team was extremely polite, calm and hamble, they did take long to resolve my issue but it was finally resolved and i am deeply happy',
#   'star_rating': 5,
#   'date': 'Oct 15, 2025'},
#  {'name': 'Elkanah Jonathan',
#   'reviews_count': 2,
#   'review_text': 'grate you guys are amazing',
#   'star_rating': 5,
#   'date': 'Oct 11, 2025'},
#  {'name': 'Augustin Ruhimbaza',
#   'reviews_count': 2,
#   'review_text': "A very good platform for money depositing and withdrawing.I'll recomand it to everyone",
#   'star_rating': 5,
#   'date': 'Oct 7, 2025'},
#  {'name': 'Olawunmi',
#   'reviews_count': 1,
#   'review_text': 'The site is very good with 100 percent accuracy and transparency in serving customers right.',
#   'star_rating': 5,
#   'date': 'Oct 7, 2025'},
#  {'name': 'Tunde Adedeji',
#   'reviews_count': 1,
#   'review_text': 'Prompt response to any complaints.Flutterwave is blessed with very good and experienced staff.They say, the first impression last longer. My first transaction with the company was a good as being beautiful.',
#   'star_rating': 5,
#   'date': 'Oct 5, 2025'},
#  {'name': 'Ogechi',
#   'reviews_count': 1,
#   'review_text': 'Flutterwave is one of the best for international payments. Making transactions and workflows easy',
#   'star_rating': 5,
#   'date': 'Oct 5, 2025'},
#  {'name': 'E. Francis Okoye',
#   'reviews_count': 14,
#   'review_text': "On behalf of my company (Alvonbot Limited) I can proudly recommend Flutterwave because Flutterwave is not just a financial management institution but it's a company that really offers a services with a full proper regulatory check to make sure that you really meet up to standard before offering you services.I can simply say that there security check is topnotch and with this, Flutterwave stands out to be a financial institution that worth using as a payment gateway.",
#   'star_rating': 4,
#   'date': 'Oct 4, 2025'},
#  {'name': 'Josiah Igbi',
#   'reviews_count': 1,
#   'review_text': 'Response from customer care was swift, and the customer care rep was also empathetic.',
#   'star_rating': 5,
#   'date': 'Oct 4, 2025'},
#  {'name': 'Epimack Chami',
#   'reviews_count': 1,
#   'review_text': 'I really appreciate Flutterwave — the platform is smooth and easy to use, and it supports many payment methods. It has been very helpful.One improvement that would make it even better is to ensure Vodacom (M-Pesa) works reliably in Tanzania. Since many people here use Vodacom, having it fully supported would make Flutterwave even more powerful and convenient.Thank you for the great service so far — looking forward to this addition.',
#   'star_rating': 4,
#   'date': 'Oct 3, 2025'},
#  {'name': 'Firstsamsung Phone',
#   'reviews_count': 1,
#   'review_text': "Nice to be here. It's my first time using this platform though.",
#   'star_rating': 5,
#   'date': 'Oct 3, 2025'},
#  {'name': 'Freda Ozobiane',
#   'reviews_count': 1,
#   'review_text': "Exceptional customer service,My issues was promptly resolved, I'm impressed",
#   'star_rating': 5,
#   'date': 'Oct 2, 2025'},
#  {'name': 'Ola Damilola',
#   'reviews_count': 1,
#   'review_text': 'I like using flutter waveIt just the slow response time',
#   'star_rating': 5,
#   'date': 'Oct 1, 2025'},
#  {'name': 'Blessing Chuks',
#   'reviews_count': 1,
#   'review_text': 'My first time using flutterwave but I must confess I love your security system very tight so this made me trust and believe that my money is save with fluterwave',
#   'star_rating': 5,
#   'date': 'Oct 1, 2025'},
#  {'name': 'Adenihun Abdul-Alim',
#   'reviews_count': 1,
#   'review_text': 'What a great platform. so seamless',
#   'star_rating': 5,
#   'date': 'Sep 30, 2025'},
#  {'name': 'Chinyere Euphemia',
#   'reviews_count': 1,
#   'review_text': 'It gives me joy to recommend flutter wave to my friends and they happy about.',
#   'star_rating': 5,
#   'date': 'Sep 30, 2025'},
#  {'name': 'isaya kimario',
#   'reviews_count': 1,
#   'review_text': "while not being solved my problem in a literal sense (making possible payouts to small solo entrepreneur to Tanzania), it was great to have been taken serious by the platform.In a world where attention to lowly startup builders by large tech companies tend to be scarce, having a human being specifically looking out to call you to address a particular problem feels like an entity with serious commitments to the well being of its customers. (Hell! I wasn't even a formal customer.)I recommend this to anyone looking for a decent online payment operations. This people know what they are doing.",
#   'star_rating': 4,
#   'date': 'Sep 28, 2025'},
#  {'name': 'Ally Beverly',
#   'reviews_count': 1,
#   'review_text': 'CoochieCleaanNigeria',
#   'star_rating': 4,
#   'date': 'Sep 28, 2025'},
#  {'name': 'a ottun',
#   'reviews_count': 2,
#   'review_text': 'I will recommend this app to anyone that wants to make transfer from one country to another. The whole Flutterwave Team is ever ready to make sure that the customer is well satisfied. They work round the clock to make sure that all transactions are completed no matter the challenges that may come up.',
#   'star_rating': 5,
#   'date': 'Sep 26, 2025'},
#  {'name': 'Osokoya Oluwagbemiga',
#   'reviews_count': 1,
#   'review_text': 'Timely response',
#   'star_rating': 5,
#   'date': 'Sep 25, 2025'},
#  {'name': 'Jessica',
#   'reviews_count': 1,
#   'review_text': 'I give flutterwave 5 stars. Just an amazing service and staff.',
#   'star_rating': 5,
#   'date': 'Sep 25, 2025'},
#  {'name': 'Amira Z.umar',
#   'reviews_count': 1,
#   'review_text': 'Flutterwave is very easy to use, you are so good thank you so much.',
#   'star_rating': 5,
#   'date': 'Sep 25, 2025'},
#  {'name': 'Wendy Plus',
#   'reviews_count': 1,
#   'review_text': 'The team made a though journey to be easy.  My problem was solved timely',
#   'star_rating': 5,
#   'date': 'Sep 22, 2025'},
#  {'name': 'Consumer',
#   'reviews_count': 1,
#   'review_text': 'Very good app I love it',
#   'star_rating': 5,
#   'date': 'Sep 22, 2025'},
#  {'name': 'Omeye Job',
#   'reviews_count': 2,
#   'review_text': 'Flutterwave is fantastic, the workers takes care of issues, sort out problems,helps make things easier, I enjoy using flutterwave.',
#   'star_rating': 1,
#   'date': 'Sep 21, 2025'},
#  {'name': 'abdullah Abdussattar',
#   'reviews_count': 1,
#   'review_text': 'Flutter wave is a globally international payment app and make business easyIt offers fast and instant payment',
#   'star_rating': 5,
#   'date': 'Sep 21, 2025'},
#  {'name': 'AfriMarket Online Hub',
#   'reviews_count': 1,
#   'review_text': 'Flutterwave staff are always very proactive. They helped us sort out issues with our payment system really quickly. There’s always someone there to respond round the clock. Happy with the service received.',
#   'star_rating': 5,
#   'date': 'Sep 20, 2025'},
#  {'name': 'Chukwunenyelight Obizue',
#   'reviews_count': 1,
#   'review_text': "Just found about flutter wave new but what I'm seeing looks like real deal",
#   'star_rating': 5,
#   'date': 'Sep 19, 2025'},
#  {'name': 'Spectrum Musics',
#   'reviews_count': 1,
#   'review_text': 'Super comfortable and convenient to use flutterwaveThanks for a swift and enjoyable customer service experienceCheers!🥂',
#   'star_rating': 5,
#   'date': 'Sep 19, 2025'},
#  {'name': 'Muhammad Mahi Yusuf',
#   'reviews_count': 1,
#   'review_text': 'They have the best customer service support I really enjoyed their timely response',
#   'star_rating': 5,
#   'date': 'Sep 18, 2025'},
#  {'name': 'Kingsley Nnadi',
#   'reviews_count': 1,
#   'review_text': 'My first experience with flutter wave was wonderful. It was a seamless transaction... Please keep it up.Nnadi.',
#   'star_rating': 5,
#   'date': 'Sep 12, 2025'},
#  {'name': 'uzzle Muncuster',
#   'reviews_count': 2,
#   'review_text': 'Fast response, and generous at solving your issue in time',
#   'star_rating': 5,
#   'date': 'Sep 11, 2025'},
#  {'name': 'Cend Studios',
#   'reviews_count': 1,
#   'review_text': 'The very best you can find in Nigeria and most parts of Africa',
#   'star_rating': 5,
#   'date': 'Sep 11, 2025'},
#  {'name': 'Kiyemba Nathan',
#   'reviews_count': 1,
#   'review_text': 'I strongly commend you for the services. Flutterwave is a reliable platform.',
#   'star_rating': 5,
#   'date': 'Sep 11, 2025'},
#  {'name': 'christian ekam',
#   'reviews_count': 3,
#   'review_text': 'I was amazing, using the app for international transactions with a low cost rate, I was surprised, is Amazing App',
#   'star_rating': 5,
#   'date': 'Sep 10, 2025'},
#  {'name': 'Omoke Shedrack',
#   'reviews_count': 1,
#   'review_text': 'wonderfull but i hope you guys keep communication and respone time fast. keep getting better.',
#   'star_rating': 4,
#   'date': 'Sep 10, 2025'}]

# %%
df = pd.DataFrame(results)

# %%
df
# Out:
#                          name  reviews_count  \
# 0         Regis H. NKUNDIMANA              1
# 1                Adigun Bunmi              1
# 2             Ajileye Olawale              1
# 3   Bismark Antwi Social life              1
# 4                    Xusilent              2
# ..                        ...            ...
# 95            uzzle Muncuster              2
# 96               Cend Studios              1
# 97             Kiyemba Nathan              1
# 98             christian ekam              3
# 99             Omoke Shedrack              1
#
#                                           review_text  star_rating  \
# 0   ⭐⭐⭐⭐⭐Excellent support and a smooth onboarding...            5
# 1   I most confess, I was wow by Flutterwave custo...            5
# 2                  Superb customer service experience            5
# 3                         I like their customer care.            5
# 4   Flutterwave has been good for my business so f...            5
# ..                                                ...          ...
# 95  Fast response, and generous at solving your is...            5
# 96  The very best you can find in Nigeria and most...            5
# 97  I strongly commend you for the services. Flutt...            5
# 98  I was amazing, using the app for international...            5
# 99  wonderfull but i hope you guys keep communicat...            4
#
#             date
# 0   15 hours ago
# 1      A day ago
# 2     3 days ago
# 3     3 days ago
# 4     6 days ago
# ..           ...
# 95  Sep 11, 2025
# 96  Sep 11, 2025
# 97  Sep 11, 2025
# 98  Sep 10, 2025
# 99  Sep 10, 2025
#
# [100 rows x 5 columns]
